# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Task-positioning" data-toc-modified-id="Task-positioning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Task positioning</a></span></li><li><span><a href="#Imports" data-toc-modified-id="Imports-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data</a></span><ul class="toc-item"><li><span><a href="#events" data-toc-modified-id="events-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>events</a></span></li><li><span><a href="#item-properties" data-toc-modified-id="item-properties-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>item properties</a></span></li><li><span><a href="#categories" data-toc-modified-id="categories-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>categories</a></span></li></ul></li><li><span><a href="#Metrics" data-toc-modified-id="Metrics-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Metrics</a></span></li><li><span><a href="#Shedule-plan" data-toc-modified-id="Shedule-plan-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Shedule plan</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Задание-4.1" data-toc-modified-id="Задание-4.1-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Задание 4.1</a></span></li></ul></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#events" data-toc-modified-id="events-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>events</a></span><ul class="toc-item"><li><span><a href="#Duplicates" data-toc-modified-id="Duplicates-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Duplicates</a></span></li><li><span><a href="#Balance--of-events" data-toc-modified-id="Balance--of-events-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Balance  of events</a></span></li></ul></li></ul></li><li><span><a href="#Feature-engeneering" data-toc-modified-id="Feature-engeneering-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Feature engeneering</a></span><ul class="toc-item"><li><span><a href="#Activity-counters-for-items-&amp;-visitors" data-toc-modified-id="Activity-counters-for-items-&amp;-visitors-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Activity counters for items &amp; visitors</a></span></li><li><span><a href="#Diversity-markers" data-toc-modified-id="Diversity-markers-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Diversity markers</a></span></li><li><span><a href="#Top-users-and-items" data-toc-modified-id="Top-users-and-items-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Top users and items</a></span><ul class="toc-item"><li><span><a href="#blading-silent-guys" data-toc-modified-id="blading-silent-guys-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>blading silent guys</a></span></li><li><span><a href="#Top-10-users" data-toc-modified-id="Top-10-users-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>Top 10 users</a></span></li><li><span><a href="#Top-10-items" data-toc-modified-id="Top-10-items-7.3.3"><span class="toc-item-num">7.3.3&nbsp;&nbsp;</span>Top 10 items</a></span></li></ul></li><li><span><a href="#Time-periods" data-toc-modified-id="Time-periods-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Time periods</a></span><ul class="toc-item"><li><span><a href="#Distribution-of-generalized-activity-on-days-&amp;-hours-&amp;-day-periods" data-toc-modified-id="Distribution-of-generalized-activity-on-days-&amp;-hours-&amp;-day-periods-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Distribution of generalized activity on days &amp; hours &amp; day periods</a></span></li></ul></li><li><span><a href="#item-properties-filtering" data-toc-modified-id="item-properties-filtering-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>item properties filtering</a></span></li><li><span><a href="#Ratings" data-toc-modified-id="Ratings-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Ratings</a></span></li></ul></li><li><span><a href="#Train-test-split-time-considering" data-toc-modified-id="Train-test-split-time-considering-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Train test split time considering</a></span></li><li><span><a href="#Collaborative-filterings,-KNN" data-toc-modified-id="Collaborative-filterings,-KNN-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Collaborative filterings, KNN</a></span></li><li><span><a href="#Matrix-factorization,-SVD" data-toc-modified-id="Matrix-factorization,-SVD-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Matrix factorization, SVD</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Hyperparam-tuning" data-toc-modified-id="Hyperparam-tuning-10.0.1"><span class="toc-item-num">10.0.1&nbsp;&nbsp;</span>Hyperparam tuning</a></span></li></ul></li></ul></li><li><span><a href="#Factorization-machine,-LightFM" data-toc-modified-id="Factorization-machine,-LightFM-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Factorization machine, LightFM</a></span></li><li><span><a href="#Recommender" data-toc-modified-id="Recommender-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Recommender</a></span></li><li><span><a href="#Notes-'n-scratches" data-toc-modified-id="Notes-'n-scratches-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Notes 'n scratches</a></span></li></ul></div>

# %% [markdown]
# ## Task positioning
#         Создан сервис, выдающий рекомендации по идентификатору пользователя.
#         Сервис обёрнут в Docker.
#         У сервиса есть понятная документация, описание функциональности.
#         Сделана презентация для менеджера с описанием принципов работы.

# %% [markdown]
# ## Imports

# %%
# table data
import pandas as pd
import numpy as np
from collections import defaultdict

#time works
from datetime import datetime

#visuals
import seaborn as sns
import matplotlib.pyplot  as plt
# %matplotlib inline

#savings 
import pickle

#Modeling
from lightfm import LightFM
from lightfm.evaluation import precision_at_k, auc_score

from scipy.sparse import coo_matrix

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from surprise import KNNWithMeans, SVD
from surprise import Dataset, accuracy
from surprise import Reader
from surprise.model_selection import cross_validate, GridSearchCV
# Out:
# C:\Users\SElen\anaconda3\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(

# %%
pd.options.display.float_format ='{:,.3f}'.format

# %% [markdown]
# ## Data

# %% [markdown]
# ### events

# %%
events = pd.read_csv('events.csv')
events.head()
# Out:
#        timestamp  visitorid event  itemid  transactionid
# 0  1433221332117     257597  view  355908            NaN
# 1  1433224214164     992329  view  248676            NaN
# 2  1433221999827     111016  view  318965            NaN
# 3  1433221955914     483717  view  253185            NaN
# 4  1433221337106     951259  view  367447            NaN

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2756101 entries, 0 to 2756100
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   timestamp      int64
#  1   visitorid      int64
#  2   event          object
#  3   itemid         int64
#  4   transactionid  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 105.1+ MB

# %% [markdown]
# ### item properties

# %%
item_properties_part1 = pd.read_csv('item_properties_part1.csv') 
item_properties_part1.head()
# Out:
#        timestamp  itemid    property                            value
# 0  1435460400000  460429  categoryid                             1338
# 1  1441508400000  206783         888          1116713 960601 n277.200
# 2  1439089200000  395014         400  n552.000 639502 n720.000 424566
# 3  1431226800000   59481         790                       n15360.000
# 4  1431831600000  156781         917                           828513

# %%
item_properties_part2 = pd.read_csv('item_properties_part2.csv')
item_properties_part2.head()
# Out:
#        timestamp  itemid property            value
# 0  1433041200000  183478      561           769062
# 1  1439694000000  132256      976  n26.400 1135780
# 2  1435460400000  420307      921  1149317 1257525
# 3  1431831600000  403324      917          1204143
# 4  1435460400000  230701      521           769062

# %%
item_properties_part2.shape
# Out:
# (9275903, 4)

# %%
#unite both parts of item properties descriptions
item_property = pd.concat([item_properties_part1, item_properties_part2], axis=0)
item_property.shape
# Out:
# (20275902, 4)

# %%
del item_properties_part1, item_properties_part2

# %%
#unique  item properties count
item_property['property'].nunique()
# Out:
# 1104

# %%
item_property.property.value_counts()
# Out:
# 888           3000398
# 790           1790516
# available     1503639
# categoryid     788214
# 6              631471
#                ...
# 782                 1
# 288                 1
# 722                 1
# 744                 1
# 769                 1
# Name: property, Length: 1104, dtype: int64

# %%
item_property[item_property.property =='categoryid']
# Out:
#              timestamp  itemid    property value
# 0        1435460400000  460429  categoryid  1338
# 140      1432436400000  281245  categoryid  1277
# 151      1435460400000   35575  categoryid  1059
# 189      1437274800000    8313  categoryid  1147
# 197      1437879600000   55102  categoryid    47
# ...                ...     ...         ...   ...
# 9275798  1433646000000  255696  categoryid  1404
# 9275823  1431226800000  390760  categoryid   324
# 9275831  1437879600000  211844  categoryid   256
# 9275873  1435460400000  444741  categoryid   511
# 9275879  1435460400000   97513  categoryid  1385
#
# [788214 rows x 4 columns]

# %% [markdown]
# Somehow items are connected via categoryid's value.

# %% [markdown]
# ### categories

# %%
category_tree = pd.read_csv('category_tree.csv')
category_tree.head()
# Out:
#    categoryid  parentid
# 0        1016   213.000
# 1         809   169.000
# 2         570     9.000
# 3        1691   885.000
# 4         536 1,691.000

# %% [markdown]
# Categories with similar parentid are supposed to be close to each other, so lets make clear connection of itemid-categoryid-parentid

# %%
categoryid = item_property[item_property.property=='categoryid'].drop_duplicates('itemid', keep='first')
#categoryid.head()

# %%
item_category = categoryid[['itemid', 'value']]
item_category.columns = ['itemid', 'categoryid']
#item_category.head()

# %%
category_parent = category_tree.set_index('categoryid').reset_index()
#category_parent

# %%
category_parent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1669 entries, 0 to 1668
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   categoryid  1669 non-null   int64
#  1   parentid    1644 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 26.2 KB

# %%
item_category.categoryid = item_category.categoryid.astype('int')
item_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417053 entries, 0 to 9275823
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   itemid      417053 non-null  int64
#  1   categoryid  417053 non-null  int32
# dtypes: int32(1), int64(1)
# memory usage: 8.0 MB
# C:\Users\SElen\AppData\Local\Temp\ipykernel_10692\1191804454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   item_category.categoryid = item_category.categoryid.astype('int')

# %%
item_category=item_category.merge(category_parent, on='categoryid', how='left')

# %%
#check
item_category[item_category.parentid==213]
# Out:
#         itemid  categoryid  parentid
# 921     406515        1455   213.000
# 3223     70084        1455   213.000
# 3257     43286        1455   213.000
# 4557    309757        1506   213.000
# 5145      1811        1506   213.000
# ...        ...         ...       ...
# 414262  116717        1455   213.000
# 414754  157617        1455   213.000
# 415676  394122         692   213.000
# 415740  432322        1455   213.000
# 417000  102607        1455   213.000
#
# [673 rows x 3 columns]

# %% [markdown]
# ## Metrics
#
# RecSys is limited to 3 candidates to offer. the metric of choise will be

# %% [markdown]
# Precision@3

# %% [markdown]
# \begin{align*}
# \textrm{precision:} \qquad P = \frac{\textrm{# correct positive}}{\textrm{# predicted positive}}\\
# \\
# \textrm{recall:} \qquad r  = \frac{\textrm{# correct positive}}{\textrm{# with condition}}
# \end{align*}

# %%
def precision_recall_at_3(predictions, k=3, threshold=0.5):
    """Return precision and recall at k metrics for each user"""

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(
            ((true_r >= threshold) and (est >= threshold))
            for (est, true_r) in user_ratings[:k]
        )

        # Precision@K: Proportion of recommended items that are relevant
        # When n_rec_k is 0, Precision is undefined. We here set it to 0.

        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0

        # Recall@K: Proportion of relevant items that are recommended
        # When n_rel is 0, Recall is undefined. We here set it to 0.

        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 0
        
        # Precision and recall will then be averaged over all users
    

    return print("precision@3:",sum(prec for prec in precisions.values()) / len(precisions), "recall@3:", sum(rec for rec in recalls.values()) / len(recalls))

# %% [markdown]
# ## Shedule plan

# %%
![Shedule.jpg](attachment:Shedule.jpg)
# Out:
# "[Shedule.jpg]" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %% [markdown]
# #### Задание 4.1
#
# Какой процент продаж обеспечивают топовые товары (точка отсечения — 1 июля)? Для топ-3 товаров по числу транзакций.
#
# Additional task:
# wich percent of sales is given by top-items (cut-point is July 01). calculate for top-3 items, base on transactions frequency.

# %%
events['date'] = pd.to_datetime(events['timestamp'], unit='ms', origin='unix')

# %%
events.duplicated().sum()
# Out:
# 460

# %%
events.drop_duplicates(inplace=True)

# %%
events.duplicated().sum()
# Out:
# 0

# %%
events_before = events[(events["date"] <= "2015-07-01")
                       & (events['event'] == 'transaction')]
events_before.groupby('itemid')['transactionid'].count().sort_values(
    ascending=False).sum()
# Out:
# 9654

# %%
top_before = events_before.groupby(
    'itemid')['transactionid'].count().sort_values(
        ascending=False).sort_values(ascending=False)[:3].index.to_list()
top_before
# Out:
# [119736, 369447, 7943]

# %%
events_after = events[(events['date'] >= "2015-07-02")
                      & (events['event'] == 'transaction')]
events_after[events_after['itemid'].isin(top_before)].groupby(
    'itemid')['transactionid'].count().sum()
# Out:
# 77

# %%
events_after.groupby('itemid')['transactionid'].count().sum()
# Out:
# 12608

# %%
round(77/12608*100, 2)
# Out:
# 0.61

# %% [markdown]
# Ответ:
# Топ-3 товара обеспечивают 0,61% от продаж при сравнении уровней продаж до 01 июля и после.
#
# Top-3 items give us 0.61% of sales comparing sales before July 01 to sales after the date.

# %%
del top_before, events_after

# %% [markdown]
# ## EDA

# %% [markdown]
# ###  events

# %%
events.columns
# Out:
# Index(['timestamp', 'visitorid', 'event', 'itemid', 'transactionid', 'date'], dtype='object')

# %%
# date aligning 
events = events.sort_values('date').reset_index(drop=True)

# %%
#dropping 'timestamp' being refactored
events.drop('timestamp', axis=1, inplace=True)

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2755641 entries, 0 to 2755640
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   visitorid      int64
#  1   event          object
#  2   itemid         int64
#  3   transactionid  float64
#  4   date           datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 105.1+ MB

# %% [markdown]
# #### Duplicates

# %% [markdown]
# Duplicates are removed in additional Product manager's task resolution.

# %%
events.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Balance  of events

# %%
events['event'].value_counts()
# Out:
# view           2664218
# addtocart        68966
# transaction      22457
# Name: event, dtype: int64

# %%
events.event.value_counts(normalize=True)
# Out:
# view          0.967
# addtocart     0.025
# transaction   0.008
# Name: event, dtype: float64

# %%
# transactions count
len(events[~events['transactionid'].isna()])
# Out:
# 22457

# %%
# unique transactions count
events[~events['transactionid'].isna()]['transactionid'].nunique()
# Out:
# 17672

# %%
sns.set_theme(style='whitegrid')
plt.figure(figsize=(25, 18))
ax=sns.catplot(data=events, x='event', kind='count', palette="ch:.18")

plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# Сильный дисбаланс классов с перобладанием просмотров над добавлением в корзину и оплатами.
#
# Strong disbalance in actions with  'view' being most frequent.

# %%
events.shape
# Out:
# (2755641, 5)

# %% [markdown]
# ## Feature engeneering

# %% [markdown]
# ### Activity counters for items & visitors

# %%
vis_act = pd.crosstab(events['visitorid'],
                     events['event'],
                     values=events['event'],
                      aggfunc='count')
vis_act.fillna(0, inplace=True)

# %%
vis_act[vis_act.transaction > 0][:5]
# Out:
# event      addtocart  transaction   view
# visitorid
# 172            3.000        2.000 33.000
# 186            1.000        1.000  2.000
# 264            2.000        2.000  3.000
# 419            1.000        1.000  4.000
# 539            2.000        1.000  4.000

# %%
vis_act.reset_index(inplace=True)

# %%
vis_act.rename(columns={
    'addtocart': "visitor_addtocart_cnt",
    "transaction": "visitor_transaction_cnt",
    "view": "visitor_view_cnt"
},
               inplace=True)

# %%
vis_act.head()
# Out:
# event  visitorid  visitor_addtocart_cnt  visitor_transaction_cnt  \
# 0              0                  0.000                    0.000
# 1              1                  0.000                    0.000
# 2              2                  0.000                    0.000
# 3              3                  0.000                    0.000
# 4              4                  0.000                    0.000
#
# event  visitor_view_cnt
# 0                 3.000
# 1                 1.000
# 2                 8.000
# 3                 1.000
# 4                 1.000

# %%
item_actions = pd.crosstab(events['itemid'], 
                          events['event'],
                          values=events['event'],
                          aggfunc='count')
item_actions.fillna(0, inplace=True)

# %%
item_actions.reset_index(inplace=True)

# %%
item_actions.rename(columns={"addtocart":"item_addtocart_cnt", "transaction":'item_transaction_cnt', "view":"item_view_cnt"}, inplace=True)
item_actions.head()
# Out:
# event  itemid  item_addtocart_cnt  item_transaction_cnt  item_view_cnt
# 0           3               0.000                 0.000          2.000
# 1           4               0.000                 0.000          3.000
# 2           6               0.000                 0.000         29.000
# 3           9               0.000                 0.000          2.000
# 4          15               3.000                 1.000         18.000

# %%
events = events.merge(vis_act, on='visitorid', how='left')
#events_df.head()

# %%
events = events.merge(item_actions, on="itemid", how='left')
events.head()
# Out:
#    visitorid      event  itemid  transactionid                    date  \
# 0     693516  addtocart  297662            NaN 2015-05-03 03:00:04.384
# 1     829044       view   60987            NaN 2015-05-03 03:00:11.289
# 2     652699       view  252860            NaN 2015-05-03 03:00:13.048
# 3    1125936       view   33661            NaN 2015-05-03 03:00:24.154
# 4     693516       view  297662            NaN 2015-05-03 03:00:26.228
#
#    visitor_addtocart_cnt  visitor_transaction_cnt  visitor_view_cnt  \
# 0                  2.000                    0.000             1.000
# 1                  0.000                    0.000             1.000
# 2                  0.000                    0.000             1.000
# 3                  0.000                    0.000             1.000
# 4                  2.000                    0.000             1.000
#
#    item_addtocart_cnt  item_transaction_cnt  item_view_cnt
# 0               4.000                 0.000         59.000
# 1               0.000                 0.000         79.000
# 2               0.000                 0.000        248.000
# 3               0.000                 0.000         63.000
# 4               4.000                 0.000         59.000

# %% [markdown]
# ### Diversity markers

# %%
#diversity range for visitors
visitor_unique_items = events.groupby('visitorid')['itemid'].nunique().reset_index()
visitor_unique_items.rename(columns={'itemid':'visitor_unique_items_cnt'}, inplace=True)

# %%
events = events.merge(visitor_unique_items, on="visitorid", how="left")
#events_df.head()

# %%
# diversity range for item
item_unique_users = events.groupby('itemid')['visitorid'].nunique().reset_index()
#item_unique_users.head()

# %%
item_unique_users.rename(columns={"visitorid":"item_unique_users"}, inplace=True)
events = events.merge(item_unique_users, on="itemid", how="left")
#events_df.head()

# %%
events.columns
# Out:
# Index(['visitorid', 'event', 'itemid', 'transactionid', 'date',
#        'visitor_addtocart_cnt', 'visitor_transaction_cnt', 'visitor_view_cnt',
#        'item_addtocart_cnt', 'item_transaction_cnt', 'item_view_cnt',
#        'visitor_unique_items_cnt', 'item_unique_users'],
#       dtype='object')

# %% [markdown]
# ### Top users and items

# %%
#top visitors
user_interaction_counts = events.groupby(
    'visitorid')['event'].count().reset_index()
user_interaction_counts.rename(columns={'event': 'total_events_user'},
                               inplace=True)

# %%
user_interaction_counts
# Out:
#          visitorid  total_events_user
# 0                0                  3
# 1                1                  1
# 2                2                  8
# 3                3                  1
# 4                4                  1
# ...            ...                ...
# 1407575    1407575                  1
# 1407576    1407576                  1
# 1407577    1407577                  1
# 1407578    1407578                  1
# 1407579    1407579                  1
#
# [1407580 rows x 2 columns]

# %%
events.shape
# Out:
# (2755641, 13)

# %% [markdown]
# #### blading silent guys

# %%
# deleting silent visitors to prevents overfitting of model 
active_users = user_interaction_counts.sort_values(by='total_events_user', ascending=False)
active_users = active_users[active_users['total_events_user']>=5]
# df1.merge(df2, how='inner', on='a')
events = events.merge(active_users, how='inner', on='visitorid')

# %%
events.shape
# Out:
# (948077, 14)

# %% [markdown]
# Заодно взглянем  на наиболее активных пользователей - героев надо знать в лицо.

# %% [markdown]
# #### Top 10 users

# %%
top_users = user_interaction_counts.sort_values(by='total_events_user', ascending=False).head(10)

plt.figure(figsize=(25,18))
ax = sns.barplot(data=top_users, x='visitorid', y='total_events_user', palette='ch:1.18')
plt.title('Top 10 active visitors')
plt.xlabel('visitor id')
plt.ylabel('Total events')
plt.xticks(rotation=45, ha='right')

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Top 10 items

# %%
item_interaction_counts = events.groupby(
    'itemid')['event'].count().reset_index()
item_interaction_counts.rename(columns={'event': 'total_events_item'},
                               inplace=True)

# %%
top_items = item_interaction_counts.sort_values(by='total_events_item',
                                                ascending=False).head(10)
plt.figure(figsize=(25, 18))
ax = sns.barplot(data=top_items,
                 x='itemid',
                 y='total_events_item',
                 palette='ch:5.48')
plt.title('Top 10 popular items')
plt.xlabel('Item id')
plt.ylabel('Total events')
plt.xticks(rotation=45, ha='right')

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center',
                va='center',
                xytext=(0, 9),
                textcoords='offset points')

plt.tight_layout()
plt.show()

# %%
events.shape
# Out:
# (948077, 14)

# %%
#cut down usless stuff
active_items = item_interaction_counts.sort_values(by='total_events_item', ascending=False)

# %%
active_items.total_events_item.value_counts(sort=True).median()
# Out:
# 4.0

# %%
active_items = active_items[active_items['total_events_item']>=5]

events = events.merge(active_items, how='inner', on='itemid')

events.shape
# Out:
# (833000, 15)

# %% [markdown]
# ### Time periods

# %% [markdown]
# Преобразуем в более удобный вид даты, выведем информацию о дне недели и времени действия.
#
# Let's transform date format to more comfortable for reading & understanding, extracting day name & time of event.

# %%
events['day_of_week'] = events['date'].map(lambda x: x.weekday())
events['year'] = events['date'].map(lambda x: x.year)
events['month'] = events['date'].map(lambda x: x.month)
events['day'] = events['date'].map(lambda x: x.day)
events['hour'] = events['date'].map(lambda x: x.hour)
events['minute'] = events['date'].map(lambda x: x.minute)

# %%
def get_time_period(hour):
    """returns one of day periods: dawn, morning, evening or night based on
    hour passed"""
    if hour >= 3 and hour <7:
        return "dawn"
    elif hour >=7 and hour < 12:
        return "morning"
    elif hour >= 12 and hour < 16:
        return "afternoon"
    elif hour >= 16 and hour < 22:
        return 'evening'
    else:
        return 'night'

# %%
events['day_period'] = events['hour'].map(get_time_period)
events['day_period'].value_counts()
# Out:
# evening      342387
# night        230814
# dawn         140255
# afternoon     86209
# morning       33335
# Name: day_period, dtype: int64

# %% [markdown]
# #### Distribution of generalized activity on days & hours & day periods

# %%
plt.figure(figsize=(25, 18))
plt.subplot(311)
ax1 = sns.countplot(data=events,
                    x='day_of_week',
                    order=events['day_of_week'].value_counts().index,
                    palette='ch:.18')
plt.title("Events quantity by days of week")
for patch in ax1.patches:
    ax1.annotate(format(patch.get_height(), '.0f'),
                 (patch.get_x() + patch.get_width() / 2., patch.get_height()),
                 ha='center',
                 va='center',
                 xytext=(0, 9),
                 textcoords='offset points')

plt.subplot(312)
ax2 = sns.countplot(data=events,
                    x='hour',
                    #order=events['hour'].value_counts().index,
                    palette='ch:.18')
plt.title("Events quantity by hour")
for patch in ax2.patches:
    ax2.annotate(format(patch.get_height(), '.0f'),
                 (patch.get_x() + patch.get_width() / 2, patch.get_height()),
                 ha='center',
                 va='center',
                 xytext=(0, 9),
                 textcoords='offset points')

plt.subplot(313)
ax3 = sns.countplot(data=events, 
                   x='day_period',
                   #order=events['day_period'].value_counts().index,
                   palette='ch:.18')
plt.title('Events quatity by day period')
for patch in ax3.patches: 
    ax3.annotate(format(patch.get_height(), '.0f'), 
                (patch.get_x() + patch.get_width()/2, patch.get_height()), 
                 ha='center',
                 va='center', 
                 xytext=(0,9),
                 textcoords='offset points')
                 

plt.tight_layout()
plt.show()

# %% [markdown]
# Минимальные уровни активности соответствуют утренним часам и времени начала рабочего дня. Пики активности приходятся на послеобеденное время, с максимумом к 20 часам. Активность начинает снижение  около 5 утра и опускается до минимума к 9-10 утра.
#
# Minimal activity levels are on morning hours and start of working day. Activity peaks are on time after lunch with maximum levels around 8 pm. Activity starts to slow down around 5 am reaching minimums around 9 & 10 am.

# %% [markdown]
# ### item properties filtering

# %%
#focusing on 10 most represented item properties
top_properties = item_property.drop_duplicates([
    'itemid', 'property'
]).groupby('property')['itemid'].count().sort_values(ascending=False)[:10]

# %%
item_property_filtered = item_property[item_property['property'].isin(set(top_properties.index))]
item_property_filtered
# Out:
#              timestamp  itemid    property                             value
# 0        1435460400000  460429  categoryid                              1338
# 1        1441508400000  206783         888           1116713 960601 n277.200
# 3        1431226800000   59481         790                        n15360.000
# 5        1436065200000  285026   available                                 0
# 10       1439089200000  450113         888            1038400 45956 n504.000
# ...                ...     ...         ...                               ...
# 9275891  1432436400000  206640         790                         n9600.000
# 9275892  1439089200000  200211   available                                 0
# 9275895  1435460400000  356920         888                      5135 1233825
# 9275897  1436065200000   74745   available                                 0
# 9275902  1442113200000  275768         888  888666 n10800.000 746840 1318567
#
# [9889797 rows x 4 columns]

# %% [raw]
# # adding top-propertiy features to data
# events = events.merge(item_property_filtered, how='inner', on='itemid')

# %%
events.shape
# Out:
# (833000, 22)

# %% [markdown]
# ### Ratings

# %% [markdown]
# Цель рекомендательной системы стандартна для коммерческой организации - увеличить прибыль. Тогда, каждому типу действий посетителя поставим в соответствие рейтинг, где высший - у 'transaction'.

# %% [markdown]
# #TODO
# Попробовать бинарный рейтинг:
# view - 0
# addtocart or transaction - 1

# %%
#events['rating'] = events['event'].apply(lambda x: 0.4 if x == 'view' else (0.6 if x == 'addtocart' else 0.8))
events['rating'] = events['event'].apply(lambda x: 0 if x == 'view' else 1)

# %%
# какие товары интересовали пользователя 1150086 - покупка и отложенные в корзину
events[events.visitorid == 1150086][events.rating >= 0.6].itemid.unique()
# Out:
# C:\Users\SElen\AppData\Local\Temp\ipykernel_10692\3389713251.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   events[events.visitorid == 1150086][events.rating >= 0.6].itemid.unique()
# array([223203, 342530, 357854,   9759,  98498, 239774, 227161, 320130,
#        316753, 272152, 337671, 294284, 118752,  93831, 419761, 212006,
#         65273, 305010,  81473,  38965,  20968, 338188, 213834, 257040,
#        250942, 332018, 227211, 268755, 248711, 214420,  89775, 148446,
#         96233,  19976, 193518, 284045,   6913, 384470, 106547, 352723,
#        295537, 352634, 450082, 127688, 428554,  61292, 461686, 372568,
#        308510, 315543, 126332, 234192, 192931, 409804, 230911,  41295,
#        188390, 415160, 373064, 254290, 354982,  44465,    546, 219512,
#        268604, 104820,  31058, 396445, 119736, 450950, 237019,   8347,
#         20740,  23762,  60980, 206241, 406025, 355752, 139515,  55251,
#          6692,  48030, 176231,  64749, 258148, 345743, 384302,  37760,
#         67614, 424506, 266900,  11279, 204494, 247601,  50648, 357132,
#        273980, 391484, 164429, 303833, 118551,  97661,  57788, 100282,
#          7943, 380014,  56782, 316472, 451027, 366177, 197642, 138427,
#        261979, 240534,  37068, 403660, 126557,  88594, 104634, 183511,
#        172894, 253615, 230807, 213102, 436034, 262105, 310620, 322489,
#         65455, 448044, 378637, 130865, 387622, 171959, 438412,  37254,
#        245168, 354484, 353142, 340825,  29196, 120098, 408504, 117677,
#        235880, 296375,  22926, 345156,   1152, 260256, 452361,  87513,
#         27994,  13417, 176869, 130371, 357133, 154485, 137697,  56303,
#        360825, 170262, 108021, 446448, 272907, 375450, 177636, 224700,
#        271268, 187549, 114121, 166122, 268081, 354585, 326173, 390984,
#         99610, 406543, 179601, 113641, 116624, 270383, 375955, 148103,
#        360877, 283916, 420960, 273872, 464998, 382885, 190000, 236512,
#        389879, 413460, 351975, 166306, 325652, 294242, 248455, 428046,
#        176484,  99187, 127631, 215051,  70662, 390380, 167126, 146081,
#        441668,  12233, 109498, 182539, 360831, 130800, 153708,  29167,
#        284463,    869, 368060, 454422, 450641, 379573,  58726,  98665,
#        291964, 448690,  25375, 322190,  36995, 387863, 156466,  95914,
#        301602, 337196, 441852, 283579,   1684, 257655, 228644, 246411,
#        126307, 219550, 217712,  19833,  75597, 210984,  71836, 385475,
#        299044, 454818, 118914, 131874, 124214, 197422, 336319,   4067,
#        174815, 190172, 266553,  57841, 130709,  73311, 293735,  79877,
#        192251, 386704, 452414, 406727, 458608, 390934,   5675, 457045,
#        232325], dtype=int64)

# %% [markdown]
# ## Train test split time considering

# %%
#align dates in data
events = events.sort_values(by='date').reset_index(drop=True)

# %%
# drop timestams as it's  transformed 
events.drop(columns=['date'], inplace=True)

# %%
split_point = int(np.round(events.shape[0] * 0.8))
events_train = events.iloc[0:split_point]
events_test = events.iloc[split_point::]
#events_test = events_test[(events_test['visitorid'].isin(events_train['visitorid']))&(events_test['itemid'].isin(events_train['itemid']))]

# %%
events_test = events_test[(events_test['visitorid'].isin(events_train['visitorid']))&(events_test['itemid'].isin(events_train['itemid']))]

# %%
events_test.shape
# Out:
# (45465, 22)

# %% [markdown]
# ## Collaborative filterings, KNN

# %% [markdown]
# Коллаборативная фильтрация предполагает, что рекомендация выдается на основании схожести профиля пользователей. Профиль при этом - набор товаров, с которыми пользователь взаимодействовал, и как именно. Так что мы ищем "соседей", смотрим, кто что покупал и в рекомендации выдаем товары с высокой оценкой пользователя со схожим профилем.

# %%
reader = Reader(rating_scale=(0, 1))

# %%
train = Dataset.load_from_df(events_train[['visitorid', 'itemid', 'rating']], reader)
trainset = train.build_full_trainset()

# %%
testset=list(zip(events_test['visitorid'].values, events_test['itemid'].values, events_test['rating'].values))

# %% [raw]
# # Used google colab to fit it and pickle it
# knn_algo = KNNWithMeans()
# knn_algo.fit(trainset)

# %% [raw]
# with open('KNN_model.pickle', 'wb') as file:
#     pickle.dump(knn_algo, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Used google colab to fit it and pickle it 
with open('KNN_model.pickle', 'rb') as file:
    loaded_KNN = pickle.load(file)

# %%
knn_predictions  = loaded_KNN.test(testset)

# %%
knn_predictions[:5]
# Out:
# [Prediction(uid=100894, iid=325623, r_ui=0, est=0.09293457943925233, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=100894, iid=325623, r_ui=1, est=0.09293457943925233, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=927278, iid=342426, r_ui=0, est=0.09293457943925233, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=1271586, iid=378637, r_ui=0, est=0.09293457943925233, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=944033, iid=3024, r_ui=0, est=0.09293457943925233, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'})]

# %%
# how to get top-n recomendations for each user
def get_top_n(predictions, n=3):
    """Return the top-n recommendation for each user from a set of predictions.
    
    args: 
        predictions(list of prediction objects) returned by the test method of algorithm
        n (the number of recomendations to out[ut for each user. Default is 3.
        
    returns: 
        a dict where keys are user row ids, values - list of tuples [(raw item id, rating)] of size n
    """
    
    # First map the predictions to each user 
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))
        
    #Then sort the predictions for each user and retrieve the k highest ones 
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = set(user_ratings[:n])
        
    return top_n

# %%
top_n_knn = get_top_n(knn_predictions, 3)

# %% [markdown]
# <div class="mark">
# </div><i class="fa fa-lightbulb-o "></i>
# Судя по  тому, что некоторым пользователям рекомендуется всего1 товар, нужно дополнять рекомендацию, скажем, наиболее покупаемыми товарами или другими - в соответствие с текущей маркетинговой стратегией компании.

# %%
top_n_knn
# Out:
# defaultdict(list,
#             {100894: {(325623, 0.09293457943925233)},
#              927278: {(342426, 0.09293457943925233)},
#              1271586: {(133814, 0.09293457943925233),
#               (216019, 0.09293457943925233),
#               (378637, 0.09293457943925233)},
#              944033: {(3024, 0.09293457943925233),
#               (91441, 0.09293457943925233),
#               (461708, 0.09293457943925233)},
#              1247126: {(78642, 0.09293457943925233),
#               (465554, 0.09293457943925233)},
#              990582: {(24734, 0), (108083, 0.09293457943925233)},
#              260253: {(31406, 0.09293457943925233),
#               (275193, 0.09293457943925233)},
#              1222579: {(133907, 0.09293457943925233),
#               (349002, 0.09293457943925233),
#               (374129, 0.09293457943925233)},
#              880463: {(142800, 0.09293457943925233)},
#              339546: {(89044, 0.09293457943925233),
#               (261979, 0.09293457943925233)},
#              215718: {(187946, 0.09293457943925233),
#               (358982, 0.09293457943925233)},
#              683066: {(337772, 0.09293457943925233),
#               (341482, 0.09293457943925233)},
#              670083: {(181067, 0.09293457943925233),
#               (272248, 0.09293457943925233)},
#              516682: {(208918, 0.09293457943925233)},
#              1347631: {(368839, 0.09293457943925233)},
#              565762: {(408019, 0.09293457943925233)},
#              828145: {(385475, 0.09293457943925233)},
#              1394949: {(78265, 0.09293457943925233)},
#              643871: {(431443, 0.09293457943925233)},
#              966752: {(162046, 0.09293457943925233),
#               (277361, 0.09293457943925233)},
#              260178: {(196038, 0.09293457943925233),
#               (196366, 0.09293457943925233),
#               (217068, 0.09293457943925233)},
#              890859: {(37394, 0.09293457943925233),
#               (120364, 0.09293457943925233),
#               (148707, 0.09293457943925233)},
#              636755: {(102925, 0.09293457943925233),
#               (404604, 0.09293457943925233)},
#              118662: {(15327, 0.09293457943925233),
#               (266729, 0.09293457943925233)},
#              1144422: {(96127, 0.09293457943925233),
#               (308438, 0.09293457943925233)},
#              140282: {(415081, 0.09293457943925233)},
#              768267: {(466385, 0.09293457943925233)},
#              783557: {(257655, 0.09293457943925233),
#               (275677, 0.09293457943925233),
#               (339545, 0.09293457943925233)},
#              1026363: {(33661, 0.09293457943925233)},
#              856239: {(315017, 0.09293457943925233),
#               (366163, 0.09293457943925233)},
#              1393007: {(42002, 0.09293457943925233)},
#              1257856: {(344071, 0.09293457943925233)},
#              961107: {(382347, 0.09293457943925233)},
#              905027: {(234570, 0.09293457943925233)},
#              933752: {(427770, 0.09293457943925233),
#               (461199, 0.09293457943925233)},
#              ...})

# %% [markdown]
# ##  Matrix factorization, SVD

# %% [markdown]
# #### Hyperparam tuning

# %% [raw]
# parameters_grid = {'n_factors': [10, 50, 100], 'n_epochs': [20, 50], 'lr_all': [0.002, 0.005], 'reg_all': [0.02, 0.1]}
#
# grid = GridSearchCV(algo, parameters_grid, measures=['rmse', 'mae'], cv=2,n_jobs=-1)

# %% [raw]
# grid.fit(train)

# %% [raw]
# # best hyperparams
# best_params = grid.best_params['rmse']
# print(f'best RMSE :{best_params}')

# %%
algo = SVD(n_factors=10, n_epochs=20, lr_all=0.002, reg_all=0.1)
algo.fit(trainset)

# %%
predictions_svd =algo.test(testset)

# %%
predictions_svd[1]
# Out:
# Prediction(uid=100894, iid=325623, r_ui=1, est=0.1750292174055196, details={'was_impossible': False})

# %%
top_n_svd = get_top_n(predictions_svd, n=3)

#print recommended items for each user: 
#for uid, user_ratings in top_n.items():
    #print(uid, [iid for (iid, _) in user_ratings])

# %%
top_n_svd
# Out:
# defaultdict(list,
#             {100894: {(325623, 0.1750292174055196)},
#              927278: {(342426, 0.034080046586118434)},
#              1271586: {(133814, 0.10598302943322883),
#               (216019, 0.04508906833814135),
#               (378637, 0.03394437163327154)},
#              944033: {(13925, 0.08871278306180888),
#               (91441, 0.11016952003317343),
#               (168504, 0.12313380553185246)},
#              1288717: {(14759, 0.14569134161082228),
#               (132137, 0.14340121754962656),
#               (183068, 0.21949779047212872)},
#              783045: {(221317, 0.04345535944607869),
#               (239255, 0.02255482965362466),
#               (325852, 0.1016198762745504)},
#              1311987: {(357626, 0.007136774192805104),
#               (403813, 0.09612251956580153)},
#              138458: {(388097, 0.13597503071064942)},
#              308215: {(448220, 0.0565371372702108)},
#              195049: {(96127, 0.08891317670110109),
#               (106322, 0.06618804899499899)},
#              1194651: {(102702, 0.06327117558525412)},
#              1379409: {(11279, 0.0753581745779257)},
#              1231742: {(299222, 0.19622059903706393)},
#              737921: {(52371, 0.22204223523981084),
#               (174489, 0.17130140979954583),
#               (342331, 0.08173557821044214)},
#              1378875: {(103112, 0.06594723588169839)},
#              1396602: {(72721, 0.05355297632400617)},
#              27191: {(108021, 0.052446628551457666),
#               (408189, 0.0013652187256687626)},
#              227238: {(131745, 0.02714780371287591)},
#              923408: {(308538, 0.003572601560746619)},
#              1247182: {(417594, 0.08915925743470154)},
#              1147438: {(3656, 0),
#               (226870, 0.033390637609739995),
#               (351125, 0.029987359278298528)},
#              1369328: {(362760, 0.11587544426063406)},
#              214459: {(188759, 0.08210989723211182),
#               (381982, 0.16955872709898795),
#               (383405, 0.0800571685747802)},
#              886051: {(385475, 0.09127188991184398)},
#              332209: {(3445, 0.14660525949501463),
#               (77075, 0.14136732753452017),
#               (299222, 0.23050683943237207)},
#              688822: {(432292, 0.03981350692638626)},
#              1118731: {(350689, 0.0029384048907882205)},
#              127448: {(266900, 0.07013832318113311),
#               (379074, 0.024539233653854922)},
#              1041563: {(312972, 0.015503602462632392)},
#              1065338: {(92341, 0.07682855073716188),
#               (218339, 0.055759916653662284)},
#              524457: {(13280, 0.12003363472920614)},
#              795383: {(196591, 0.33718205126473616),
#               (343377, 0.30833206212089326)},
#              483429: {(428085, 0.026955264005342858)},
#              1309565: {(382421, 0.01255517122418075)},
#              925788: {(13825, 0.11027023327253592)},
#              1117312: {(297726, 0.15510579953117995)},
#              538729: {(869, 0.06988485359174067)},
#              744145: {(28657, 0.06429682054478027)},
#              648772: {(185366, 0.019308850677137415)},
#              987972: {(133490, 0.09684919148285018),
#               (320275, 0.10271011100494679)},
#              1056963: {(9629, 0.11439653992651642),
#               (59467, 0.08716088906829464),
#               (174778, 0.033603364553750126)},
#              110597: {(16344, 0.46905381513257827),
#               (230850, 0.368494977618618),
#               (441813, 0.4212972126831813)},
#              772678: {(361734, 0.052710777186140007)},
#              299473: {(170283, 0.04656476998421375)},
#              368525: {(403576, 0.12090189491877275)},
#              978698: {(354447, 0.04355727545469136)},
#              454229: {(245158, 0.1444741253659378),
#               (395161, 0.11547825118927371),
#               (425925, 0.09195693119873835)},
#              9087: {(159792, 0.06765269472261849),
#               (221501, 0.07561163762594704)},
#              545160: {(442655, 0.040594201480296306)},
#              1249661: {(131745, 0.05893618103712337)},
#              230796: {(190390, 0.07715871837104887),
#               (221533, 0.05755600191634649)},
#              1249611: {(56323, 0.0420552263453073),
#               (90247, 0.023292567090151796),
#               (99020, 0.08212501241527118)},
#              910738: {(423395, 0.1408195419895255)},
#              1003169: {(122941, 0.13489264283519428),
#               (234255, 0.16224385918172152)},
#              906125: {(251962, 0.0422344490288249)},
#              443422: {(264521, 0.11055943750704367),
#               (288340, 0.09188345863931809),
#               (454818, 0.0682436082095815)},
#              1388327: {(344902, 0.03800802295506571),
#               (400600, 0.0314176976120131)},
#              1372168: {(282385, 0.08120821507004947)},
#              105095: {(130500, 0.034709434632960806)},
#              487437: {(12746, 0.057778954601317045)},
#              405509: {(93941, 0.04211042746335279),
#               (465019, 0.1293672739061098)},
#              87796: {(256769, 0.0555629463064994)},
#              1062581: {(192564, 0.009508283163467364)},
#              70635: {(448018, 0.06489786942499719)},
#              381739: {(2076, 0.12648843288181566)},
#              671264: {(441653, 0.1701209374197945)},
#              425401: {(247601, 0.08822382338156454),
#               (324514, 0),
#               (397946, 0.035576778766742236)},
#              439029: {(66737, 0.10191808021091543)},
#              519144: {(159822, 0.10232778954253999),
#               (334342, 0.12828884886409517),
#               (416253, 0.06516319333050531)},
#              950342: {(144102, 0.020476370068933998),
#               (229382, 0),
#               (279373, 0)},
#              209317: {(461686, 0.17164454060678241)},
#              1334243: {(138427, 0.10156385558750457)},
#              783500: {(237147, 0.07309769444126875),
#               (329443, 0.007725481134530268),
#               (334867, 0.005493482432308766)},
#              867433: {(347244, 0.007006501042581655)},
#              142509: {(420631, 0.10855780995846753)},
#              268151: {(177152, 0.017313361703930358)},
#              233567: {(39238, 0.05995954457642351)},
#              1172439: {(78006, 0.12160905401690174)},
#              153322: {(461686, 0.11458087983333999)},
#              34893: {(208460, 0.1020749766533634)},
#              732236: {(374212, 0.016915305386550186)},
#              665834: {(428980, 0.055366817019775756)},
#              391507: {(46156, 0.2084313516640432),
#               (136854, 0.09174920436187092)},
#              22074: {(195759, 0.07815082430432671),
#               (371551, 0.059821625363862485)},
#              517180: {(305954, 0.03222966094441441),
#               (349987, 0.08956398286555736)},
#              409230: {(89342, 0.07116089288556263),
#               (262638, 0.08849229579308061)},
#              167384: {(13855, 0.08247641841611936),
#               (193286, 0.07056760727900584)},
#              731398: {(233722, 0.05495055924981462),
#               (302569, 0.09667614299082353),
#               (349273, 0.09872574240632878)},
#              681459: {(194731, 0.01312599652189464),
#               (258148, 0.13137864878886354)},
#              496858: {(110151, 0.021701688385561163)},
#              985950: {(111663, 0.04014517772270615)},
#              270545: {(49125, 0.04276807666932629)},
#              420947: {(225826, 0.026104795938435437)},
#              207874: {(237952, 0.004443546567526692),
#               (439956, 0.014938425831412909)},
#              60236: {(222888, 0.1202326277297289)},
#              677707: {(358211, 0.05013364820268994)},
#              163172: {(157037, 0.07369896950688215)},
#              985937: {(183411, 0.08999213644925358)},
#              1018528: {(50671, 0.06855184935279172)},
#              1222374: {(228611, 0.08507729241162737), (339736, 0)},
#              946782: {(294312, 0.0254039662883119)},
#              1197343: {(9877, 0.3838192818855621),
#               (283492, 0.40291142757092746),
#               (461686, 0.4728908622656175)},
#              1349746: {(73616, 0.11213714644739801),
#               (259920, 0.16565368646017814),
#               (376843, 0.1228870358630742)},
#              1014047: {(56666, 0), (69303, 0.025513185196154524)},
#              1128663: {(358594, 0.014068081553504828)},
#              823257: {(97873, 0.10632209059426004),
#               (100393, 0.08999375126571561),
#               (391992, 0.08535305178639796)},
#              128412: {(109924, 0.05885920414997143),
#               (272455, 0.02662335729551397),
#               (408433, 0.07848783705594585)},
#              574675: {(63499, 0.01138078750711978)},
#              294533: {(219034, 0.04070526951451804)},
#              602115: {(368403, 0.015048296282625283)},
#              533158: {(133966, 0.07318318629997349)},
#              1172519: {(222888, 0.17446134750267955)},
#              446336: {(214790, 0.04035771570132788),
#               (241892, 0.021677448828462655)},
#              1044018: {(106359, 0.10615704582660819),
#               (244528, 0.06498948565265983)},
#              277725: {(92161, 0.0545889302265946), (114340, 0)},
#              918825: {(200296, 0.15629680566700113),
#               (264778, 0.06354017750192834),
#               (426031, 0.09239383763903138)},
#              269420: {(458945, 0.01625564348878701)},
#              1178061: {(52022, 0.020558423395040368)},
#              1284857: {(178102, 0.0825636807609942)},
#              876743: {(15903, 0.02753240497513911)},
#              1034836: {(439679, 0.09223729415333826)},
#              711327: {(75010, 0.024010645258834923)},
#              857150: {(352493, 0)},
#              1040463: {(422525, 0.009701654281968335)},
#              1236520: {(133907, 0.08126565250489548),
#               (402510, 0.11684317151150661)},
#              213772: {(363109, 0.0029517479828850904)},
#              971132: {(139191, 0.1384247490335352)},
#              386805: {(345287, 0.006383305841193173)},
#              932712: {(46130, 0.04006100278259253)},
#              82584: {(14957, 0.03168810077106283)},
#              722879: {(322078, 0.05297773014496354)},
#              854743: {(462188, 0)},
#              1013524: {(351101, 0.17596847135644395)},
#              434890: {(451806, 0.1255362573442154)},
#              986876: {(213051, 0.07227877666717557)},
#              1254607: {(332991, 0.03125561313374357)},
#              986413: {(186491, 0.18687348675803192),
#               (355741, 0.1528348487119407),
#               (364916, 0.17142067485113086)},
#              469019: {(10572, 0.21664844323153956),
#               (333039, 0.2562678691300139)},
#              629387: {(13925, 0.057851473786571815),
#               (340960, 0.019145800230466956)},
#              376743: {(189764, 0.13612213305566895),
#               (257748, 0.07225026665367401)},
#              285132: {(225016, 0.07750309241150986)},
#              1158015: {(330647, 0.03924958897465092)},
#              417194: {(396633, 0.08402786140510334),
#               (442131, 0.1106518077110493)},
#              970186: {(303637, 0.03825560211969795),
#               (341700, 0.0401499922809056)},
#              597003: {(257040, 0.07303177261290716)},
#              976025: {(192414, 0.024920418096289292),
#               (437789, 0.05078082277373824)},
#              1231368: {(3759, 0),
#               (147879, 0.025167908105160543),
#               (219319, 0.03505032144609578)},
#              983677: {(383715, 0.0013071843356558706)},
#              1137090: {(9308, 0.16298037462862208),
#               (400673, 0.16697219138135416)},
#              133770: {(106322, 0.13606160246379198),
#               (134751, 0.04029416521480331),
#               (343190, 0.09841026132607625)},
#              262357: {(9877, 0.08859914941105741)},
#              1390085: {(113155, 0), (271896, 0.006506882612209851)},
#              548948: {(13783, 0.1493442785278055),
#               (82707, 0.1313892489070751),
#               (188550, 0.0831716051047794)},
#              1030744: {(278893, 0.03951949482979292)},
#              485699: {(161205, 0.13349737430176786)},
#              777806: {(196398, 0.19188371823874287),
#               (242981, 0.05470394160085529)},
#              488858: {(262982, 0.33451307432068317)},
#              709082: {(209056, 0.06192761534496009)},
#              204853: {(303715, 0.09245070033548096)},
#              1369309: {(4332, 0.052762227582027074)},
#              235976: {(361856, 0.1533468352670156)},
#              232649: {(394792, 0.10549655377054713)},
#              54791: {(296619, 0.005968502611373078)},
#              554606: {(23055, 0.1917739007277477),
#               (222888, 0.18581254992789345),
#               (445258, 0.19141966913321934)},
#              32277: {(354753, 0.022433941318495593)},
#              933225: {(108984, 0.16275752419775755),
#               (379013, 0.058476301160896506)},
#              140357: {(190000, 0.07682126287397367),
#               (234255, 0.06266546256346844),
#               (306380, 0.0818244209163368)},
#              672003: {(133647, 0.07334847321333864)},
#              66685: {(326785, 0.07839794771063718)},
#              349591: {(52011, 0.0106840955858346)},
#              801373: {(386112, 0)},
#              102479: {(372732, 0.04330197136227501)},
#              381941: {(280122, 0.02913150079214137)},
#              471992: {(66146, 0.36740223367806313),
#               (357859, 0.5105470195063496)},
#              1087246: {(6853, 0.016787239940323013)},
#              97561: {(75509, 0.15946054777172952)},
#              1194351: {(331875, 0.05539140911151207)},
#              1235682: {(275339, 0.049358097385987176),
#               (297060, 0.13276862578986315),
#               (326849, 0.05338341197178468)},
#              505495: {(259202, 0.04439677069729561)},
#              146255: {(396336, 0.01818597133090487)},
#              1282185: {(81045, 0.04936674491065372), (144053, 0)},
#              422632: {(13518, 0.026642552609531793)},
#              1094964: {(4613, 0.04061161112879452),
#               (141424, 0.060995704361268346),
#               (348947, 0.019594652432867305)},
#              1172198: {(414460, 0)},
#              78083: {(212319, 0.06534507236936105)},
#              411143: {(245520, 0.08329224370249061),
#               (401268, 0.10420259473075616)},
#              699654: {(428891, 0.10311861509676838)},
#              905060: {(351551, 0.03512978491368286),
#               (364063, 0.05798741642899998)},
#              1160332: {(63102, 0.10325603353669023)},
#              1399767: {(212042, 0.04376569345835089)},
#              1242500: {(422671, 0.0997187689036545),
#               (441668, 0.1007173759310454)},
#              582861: {(119736, 0.08559985826589832)},
#              551844: {(223355, 0.04946169553253672)},
#              835425: {(148123, 0.11062426101785228)},
#              1198243: {(335268, 0.08674387180403766)},
#              1083704: {(143866, 0.009438166420414314)},
#              32252: {(133138, 0.004535365247425694)},
#              360716: {(2070, 0.021553846102918085)},
#              713183: {(12173, 0.08631181956843648)},
#              788375: {(29162, 0.039682920590320706)},
#              783846: {(438484, 0.12500589769296325)},
#              73305: {(212156, 0.030454312420061167)},
#              473439: {(202690, 0.06589564435794001),
#               (224605, 0.06522115893477429)},
#              118056: {(349335, 0.05667595843381531)},
#              638573: {(321668, 0.07241575624811364)},
#              20301: {(34977, 0.13682950888719767), (130428, 0)},
#              1306769: {(262920, 0.04174020760330351)},
#              976904: {(102750, 0.03674342910930445)},
#              1318953: {(153401, 0.04553647513352015)},
#              610819: {(352115, 0.05713994857024466)},
#              191490: {(108198, 0.09129049177613681),
#               (452628, 0.03316385086197911)},
#              37093: {(206564, 0.13029148558685594),
#               (421788, 0.10115587962878388),
#               (454781, 0.111309924228656)},
#              494995: {(45821, 0.08887770723063299)},
#              772: {(108083, 0.026941608606337222)},
#              569234: {(46253, 0.09879610875507697)},
#              675498: {(48030, 0.13945220753217025),
#               (264436, 0.035372313159733625)},
#              413556: {(237318, 0.22171367765629255),
#               (276494, 0.21277749403020002)},
#              514220: {(135446, 0.0015646668530580011)},
#              395727: {(1931, 0.02747834740516262)},
#              554007: {(24693, 0.02882772444450421)},
#              232152: {(90892, 0.021620301163051043),
#               (228083, 0.06733364884538921)},
#              944550: {(17108, 0.024634845701302782)},
#              112411: {(84647, 0.05324018412162136)},
#              155176: {(86342, 0.056588133575858075)},
#              1090773: {(323248, 0.01401834598072663)},
#              1322350: {(98071, 0.03983739136147233)},
#              334685: {(299667, 0.09879288953428561)},
#              223972: {(172497, 0.05848450444461888)},
#              106989: {(27283, 0.09976102104335324),
#               (89641, 0.06126234570076956),
#               (389472, 0.08346545795575391)},
#              265485: {(40355, 0.05548758795340685),
#               (242188, 0.04235488903358428),
#               (334575, 0.06289763227272069)},
#              1109628: {(162657, 0.03060271258098776)},
#              534227: {(241973, 0.04518011031631329)},
#              1018173: {(425899, 0.01693834382667566)},
#              819599: {(288781, 0.00311856213773605)},
#              603581: {(219186, 0.008881828046156677)},
#              934666: {(258508, 0.05849311427060054)},
#              589509: {(168276, 0.04732508369734408),
#               (436915, 0.0745980538231142)},
#              173863: {(46156, 0.22947525381969064),
#               (213834, 0.2532541870876021),
#               (317691, 0.22732770431478555)},
#              1219951: {(10885, 0.08079865574057284),
#               (338660, 0.08273963572423047)},
#              565647: {(84997, 0.029500349005660068)},
#              1126682: {(395435, 0.0326228261825359)},
#              124971: {(140527, 0.2538040808906603),
#               (187138, 0.13998916879809226)},
#              174396: {(254290, 0.10328593207698479)},
#              418408: {(235281, 0.07065516551382045)},
#              679217: {(152052, 0.10975669923974816)},
#              881959: {(180362, 0.038008625215182196)},
#              965961: {(161959, 0.04396715936586254),
#               (291689, 0.04279207931104537)},
#              674163: {(5821, 0.12303099100954337),
#               (276240, 0.0792876261754124),
#               (288340, 0.10079979646847859)},
#              916961: {(27897, 0.08706943359631397)},
#              816308: {(11250, 0.10085253825377397),
#               (136316, 0.09807117070109579)},
#              248475: {(411877, 0.04124448329831135)},
#              542631: {(218329, 0.13285375633272378)},
#              1349443: {(144483, 0.025779191444145866)},
#              639801: {(226224, 0.07642824067032514)},
#              321726: {(202170, 0.0075419650226393325)},
#              836044: {(29741, 0.03838651574387757)},
#              1150086: {(213834, 0.31791189159658406),
#               (457970, 0.3139336044187099)},
#              569960: {(295553, 0.027082484284334667)},
#              725278: {(446998, 0.023704377949703884)},
#              208929: {(368462, 0.07789875539397403)},
#              1229244: {(14434, 0.035689513978573686),
#               (118823, 0.0461787957537564)},
#              1007372: {(420850, 0.11189754185675466)},
#              129611: {(23626, 0.11849823688113922),
#               (349033, 0.01874972290814525),
#               (435594, 0.05219812877438773)},
#              37430: {(410889, 0.09278095540970165)},
#              361041: {(251396, 0.12474595386405873)},
#              786921: {(134264, 0.07065324236197984),
#               (135165, 0.07640168545907083)},
#              1248077: {(45622, 0.0737998962120382),
#               (153708, 0.06803502316663379)},
#              1051462: {(319380, 0.05883387153790456)},
#              390888: {(100918, 0.17218757363102952)},
#              50921: {(205802, 0.07212111095762297),
#               (346203, 0.08700136177039716),
#               (354288, 0.03907940172257788)},
#              860107: {(38122, 0.09140675705755733),
#               (356668, 0.038147990212420206)},
#              935805: {(416979, 0.05672502049313906)},
#              1075412: {(435618, 0.047240085503667074)},
#              601451: {(231009, 0.10693872133045881)},
#              1393209: {(116493, 0.10349653270470466)},
#              208924: {(196927, 0.07538827967131813)},
#              992753: {(104891, 0.10193081505377663)},
#              152963: {(216266, 0.369665934852563),
#               (245985, 0.366013519149855),
#               (288525, 0.40066606567957525)},
#              247235: {(78268, 0.24726870238658866),
#               (213834, 0.23617653511530445),
#               (449391, 0.21653927860883404)},
#              1326742: {(231154, 0)},
#              1336835: {(213834, 0.2834331266911906),
#               (438823, 0.3503644607598906)},
#              631389: {(101827, 0.13340504933353622),
#               (352822, 0.023065613454521527),
#               (428272, 0.023842791110641214)},
#              1021129: {(360986, 0.08489850007217639)},
#              51826: {(313163, 0.040498799922553175)},
#              1180967: {(22814, 0.0836840564903447),
#               (427459, 0.15274263191916668)},
#              1363207: {(196659, 0.003990939898300636)},
#              842547: {(159780, 0.1111327559324486)},
#              298473: {(399476, 0.04120061041178504)},
#              507774: {(242910, 0.10109316719075863),
#               (347521, 0.060626170759857836)},
#              390675: {(459520, 0.08986782914664297)},
#              895999: {(109598, 0.1323805513984978),
#               (213834, 0.1737331925790401),
#               (361777, 0.16454872683576738)},
#              261738: {(181146, 0.039627584438967245),
#               (413067, 0.03723579048800062),
#               (425458, 0.10787263151257112)},
#              1126569: {(104116, 0.21075408680451913),
#               (222888, 0.15108907190056858),
#               (409804, 0.18882687322448058)},
#              703777: {(287864, 0.05344299988020552)},
#              1338951: {(118914, 0.05236057884769561),
#               (355994, 0.06284736811169743),
#               (382419, 0.053582189961255924)},
#              488451: {(159792, 0.08753675174929434),
#               (361554, 0.15878055209629083)},
#              254028: {(447397, 0.06145685284341982)},
#              95639: {(377644, 0.04014216941628486)},
#              393964: {(105810, 0.016047808127133467)},
#              123298: {(322564, 0.026201425329348025)},
#              1119917: {(56782, 0.08079972170304807),
#               (143860, 0.10915674058762997),
#               (275625, 0.08075564316241363)},
#              474818: {(260152, 0.016572699073597243),
#               (358513, 0.0065992188860488285)},
#              530559: {(213834, 0.3335408644161305)},
#              932939: {(371551, 0.08767845582562273)},
#              1345324: {(83277, 0.08303791956732498),
#               (212025, 0.14932643358445385)},
#              13239: {(450082, 0.12299785016181879),
#               (462430, 0.0278729301827933)},
#              963348: {(98840, 0.13448284321066553),
#               (145254, 0.14096721387996752),
#               (414654, 0.16311663585152533)},
#              518659: {(321089, 0.19406622626232542),
#               (409804, 0.25867208400751657),
#               (436115, 0.17314850521845246)},
#              547699: {(398452, 0.06170992984890018)},
#              1050820: {(121458, 0.07133429440268099)},
#              1297347: {(135570, 0.027298276663751148)},
#              1310994: {(9014, 0.12819376319438125),
#               (65052, 0.05030128537433433)},
#              1291340: {(29196, 0.10815741836334976)},
#              356666: {(241441, 0.007804297972171359),
#               (336578, 0.05758750253082477)},
#              198153: {(46156, 0.19980438573811532),
#               (207825, 0.13493794313228855),
#               (372395, 0.14458679237324398)},
#              1003583: {(47889, 0.07129601490782693),
#               (155843, 0.11355874455230876),
#               (396445, 0.09914393724998068)},
#              134966: {(18155, 0.08723844050116873),
#               (388558, 0.08900136885595492)},
#              1403769: {(183756, 0.1822145915804253),
#               (312728, 0.1230426074304116),
#               (453192, 0.12383264970172513)},
#              1238753: {(62549, 0.06772505914430776),
#               (66752, 0.04885242443391898),
#               (85732, 0.20593728914318674)},
#              131249: {(96127, 0.09026022111617932),
#               (133647, 0.1063296598809329)},
#              983164: {(443123, 0.059634442825986726)},
#              312612: {(271180, 0.048677193862272344)},
#              638253: {(4968, 0.08199887900676202)},
#              1327144: {(375150, 0.13147481803337624)},
#              1272794: {(413901, 0.003145751515038228)},
#              431482: {(432912, 0.08492008147128305),
#               (462188, 0.034415948722855826)},
#              834934: {(68000, 0.05126669985164342),
#               (460614, 0.030187950373294102)},
#              1018974: {(89464, 0.08266784137062891),
#               (222888, 0.16590710868925826),
#               (253175, 0.0782609303707876)},
#              118864: {(259243, 0.07104190293479826)},
#              1217669: {(218406, 0.045245382452227034)},
#              1115702: {(25375, 0.029541824671510723),
#               (42212, 0.007851582523112867),
#               (322190, 0.04880595219192038)},
#              844848: {(328646, 0.04436916026343426)},
#              1073958: {(206970, 0.08147789348810011),
#               (409804, 0.18012571921392992),
#               (417927, 0.08476794599886892)},
#              375922: {(302563, 0.0226836763748949)},
#              229157: {(131385, 0.13397939939511344),
#               (426122, 0.0832541063841947)},
#              1229972: {(32701, 0.003561625999974276)},
#              528709: {(91888, 0.08931852762803914)},
#              955802: {(416952, 0.0935332573109208)},
#              1072442: {(61001, 0.0500930770746134),
#               (272976, 0.0343961358837132)},
#              109232: {(272455, 0.04820556622047734)},
#              1165148: {(248626, 0.1478389292714244),
#               (338794, 0.1429800502669029)},
#              51824: {(18886, 0.05846066871397762)},
#              1053057: {(177555, 0.04568056505026607),
#               (252860, 0.12320935811894601),
#               (392605, 0.06324888345423822)},
#              641403: {(68337, 0), (159956, 0.048703770412248756), (224297, 0)},
#              962342: {(101184, 0.1689222075735494),
#               (441813, 0.16190756388143626)},
#              734021: {(213356, 0.16677165400389699)},
#              1098176: {(152262, 0.002137309718451455)},
#              797409: {(157187, 0.4934784787098807),
#               (448494, 0.4946089176785709)},
#              1329523: {(88536, 0.15505344613479857)},
#              1318136: {(113635, 0.09012001603441888),
#               (183511, 0.08563599029754171),
#               (441852, 0.09073560611749462)},
#              1218480: {(81104, 0.2429387752464432)},
#              1206231: {(311694, 0.02255466973445127),
#               (316508, 0.002579547205209174),
#               (431876, 0.08067502315863273)},
#              228792: {(305558, 0.06504923102571697),
#               (335584, 0.05827671209371643),
#               (460188, 0.07769478456761339)},
#              1122563: {(192875, 0.021866037011216834),
#               (396588, 0.07992666655215956)},
#              778287: {(7943, 0.09757148506806232)},
#              1351335: {(29196, 0.06015146106247367),
#               (100393, 0.017818731633192204)},
#              923325: {(67094, 0.057931430403097416)},
#              601836: {(50895, 0.07317931474689467),
#               (170390, 0.1356248508328853),
#               (214495, 0.08040258167494888)},
#              353697: {(14434, 0)},
#              1346690: {(134255, 0.013873314417149856),
#               (308704, 0.05719307556372788)},
#              940909: {(244458, 0.08356799680105143)},
#              1327003: {(234857, 0)},
#              1214415: {(65426, 0.10454879319291191),
#               (368702, 0.0674914976898667),
#               (384470, 0.15259637930459188)},
#              798581: {(235796, 0.09464919437203209)},
#              1239950: {(71097, 0.14904269605261822),
#               (274756, 0.2134444945355629)},
#              179362: {(281400, 0.09727744620877538),
#               (402025, 0.08479044648027366),
#               (441265, 0.1945341281720063)},
#              756545: {(174436, 0.2045814945964751)},
#              702328: {(201987, 0.046016977912053676)},
#              761849: {(150185, 0.04554279560926624),
#               (269177, 0.02444513577604707)},
#              977753: {(101156, 0.17718365906612205),
#               (222888, 0.16869422589152677)},
#              1341887: {(157747, 0.09188335645521986),
#               (396619, 0.03534709631814964)},
#              24238: {(215125, 0.044058075499467386)},
#              713551: {(174815, 0.04309593725345243),
#               (332018, 0.05465935264174486),
#               (464123, 0.05957063954301156)},
#              1332095: {(96904, 0.026796202985494504)},
#              196162: {(422547, 0.017881970630640925)},
#              503070: {(215363, 0.07856186963158267)},
#              949784: {(175768, 0.07554505040389686)},
#              1147145: {(108696, 0.03934844243274087)},
#              302195: {(136674, 0)},
#              802043: {(199568, 0.13805790722713634)},
#              876473: {(192251, 0.06560544944283342)},
#              1340592: {(90238, 0.06780171829226073),
#               (416758, 0.034695557031117395)},
#              1360089: {(375353, 0)},
#              871837: {(356339, 0.01909832306371801),
#               (358211, 0.052796751908844294),
#               (451360, 0.013748307242560938)},
#              402275: {(48803, 0.018729016992164144),
#               (160793, 0.02559164694839993),
#               (362634, 0.19408915051781955)},
#              559415: {(75033, 0.036127802065967045)},
#              632163: {(321657, 0.07656191919083193),
#               (373600, 0.07457618191795991)},
#              316850: {(222888, 0.16929634021670548),
#               (285948, 0.16589451227019064)},
#              1235647: {(316980, 0.03701972604986427)},
#              1227408: {(384302, 0.06100678574709659), (466135, 0)},
#              735823: {(457514, 0.03041047195021794)},
#              602190: {(7730, 0.06043505534495529),
#               (179728, 0.12047141527680605),
#               (276494, 0.10893408318808262)},
#              149305: {(272976, 0.1370053870633487)},
#              48650: {(1766, 0.08268394265626706)},
#              974895: {(344603, 0.08793774637350178),
#               (419387, 0.016889899403006458),
#               (428002, 0.07989343831041015)},
#              295251: {(217993, 0.07243399254150847),
#               (300466, 0.025542942403757776)},
#              1078512: {(19873, 0.06992924734032378),
#               (125780, 0.05301408767954356)},
#              74943: {(242188, 0.025481700393654983)},
#              709299: {(165245, 0.04895596779685818)},
#              686800: {(19462, 0.09670358052884709),
#               (64137, 0.06589526275018448)},
#              436617: {(36315, 0.0168132005883891)},
#              546086: {(237244, 0.06435027797937805),
#               (246075, 0.0658523196156978),
#               (267236, 0.0496893245753859)},
#              638482: {(16775, 0.09451906787904274),
#               (358906, 0.08500638319909765),
#               (438823, 0.22974893016571948)},
#              586023: {(259913, 0.08497403005596445),
#               (352068, 0.11418487928636056)},
#              101175: {(234215, 0.3149634998835003),
#               (288887, 0.3252959872541784),
#               (411198, 0.24964580713853937)},
#              550170: {(313782, 0.020668959389944605)},
#              244531: {(149723, 0.16926698907185103)},
#              721733: {(90784, 0.04484858000242618),
#               (226374, 0.05203436282344941),
#               (374554, 0.08377136981350536)},
#              879654: {(123154, 0.07992025819246026),
#               (162644, 0.03701572824973977)},
#              932290: {(125831, 0.10327349002957928),
#               (303845, 0.039991711604682165)},
#              449282: {(252183, 0.10202922007750606)},
#              890837: {(222775, 0.04448407143239627),
#               (358485, 0.030280419877094823),
#               (379337, 0.056303767278937725)},
#              200979: {(302126, 0.1712141497283591)},
#              969726: {(454818, 0.09705034030661605),
#               (455183, 0.052878970708005055)},
#              761783: {(134131, 0.3274138652848598),
#               (272152, 0.34006803199126845),
#               (320130, 0.3095235666189882)},
#              478191: {(146023, 0.008837704117824497)},
#              328384: {(105334, 0.10598062187156629),
#               (294717, 0.09611828906784155),
#               (368159, 0.0941558156429621)},
#              225936: {(27216, 0.07771231778335058),
#               (456199, 0.10467312328659192)},
#              398154: {(414605, 0.06466077231093836)},
#              1187632: {(2469, 0.019566142845972564),
#               (322341, 0),
#               (465387, 0.0564695123439835)},
#              1241358: {(104476, 0.07584729160303949),
#               (293737, 0.08757097690091706)},
#              534325: {(396071, 0.03467272244409622)},
#              1076529: {(183120, 0.0643906953929612)},
#              471950: {(72273, 0.14977538786806313),
#               (205128, 0.1109918972012335)},
#              890201: {(356677, 0.06817996694569266),
#               (374962, 0.09946156029279653)},
#              940994: {(9877, 0.07880271957354969)},
#              585456: {(255005, 0.028746230881939033),
#               (341387, 0.09721582261761008),
#               (409881, 0.060169238955969324)},
#              76113: {(16344, 0.19162246424065071)},
#              454044: {(147559, 0.017784637491546577),
#               (447133, 0.000646199011367754)},
#              248328: {(198784, 0.03003386877671716),
#               (266085, 0.0388598995138678),
#               (339987, 0.04368604393041717)},
#              1157308: {(4240, 0.07955522532127896),
#               (87081, 0.15722001326324264)},
#              885139: {(150215, 0.07506849221319739),
#               (272701, 0.04194567628806929),
#               (357383, 0.0628015925464072)},
#              245638: {(71274, 0.06154469400550268)},
#              772262: {(240160, 0.2227821362526702)},
#              327079: {(96149, 0.09334774762037949),
#               (465565, 0.05209517526499218)},
#              150172: {(83366, 0.037971933759953024)},
#              912708: {(199931, 0.01998943965767261)},
#              1333267: {(304876, 0.03777729061986661),
#               (355605, 0.039112210758436745)},
#              507029: {(453823, 0), (465621, 0.0813069884199962)},
#              704593: {(15417, 0.12944655209999859),
#               (305782, 0.03588852976261077)},
#              45887: {(136524, 0.004619107711318061),
#               (136768, 0.13392937871972663),
#               (323455, 0)},
#              316600: {(255093, 0.16261098441942723),
#               (432748, 0.17250781712593302)},
#              451170: {(258866, 0)},
#              366071: {(109132, 0.07774149740745355)},
#              669907: {(97307, 0),
#               (222888, 0.1949480686617608),
#               (461686, 0.17668448093011965)},
#              224462: {(93428, 0.04223751845600295)},
#              693709: {(226647, 0.15810149997283152),
#               (409804, 0.18273456595574353)},
#              339496: {(51378, 0.09350953394219769)},
#              911286: {(57301, 0.1446000532414454),
#               (119736, 0.17059755987922504)},
#              286718: {(3136, 0.0702477445999209),
#               (81182, 0.06777506761402982),
#               (417927, 0.11674564514605752)},
#              566598: {(99961, 0.07273918176332053)},
#              1289457: {(19789, 0.27239778906470113)},
#              1053803: {(36995, 0.10591211490371977)},
#              309897: {(4564, 0.005500880803219317),
#               (201882, 0.04855910111290978)},
#              595640: {(248455, 0.17567592421845338)},
#              862509: {(73593, 0.15561005484801996)},
#              383535: {(327191, 0.02616588512433727)},
#              441738: {(35608, 0.13431676816090116),
#               (171878, 0.1472542333402552),
#               (382130, 0.22197317631696734)},
#              517829: {(182455, 0.026479004827906924),
#               (412388, 0.10451275605480614)},
#              655482: {(33907, 0.013731838714796822)},
#              1015599: {(2567, 0.06390283240559987),
#               (312728, 0.07656754394557581),
#               (358348, 0.09528243371556529)},
#              124267: {(379092, 0.018465052106359743)},
#              724334: {(4067, 0.05356518670394366),
#               (253156, 0.14381813410916836)},
#              1324107: {(334878, 0.07188780763644936)},
#              682681: {(126396, 0.014737551336743069),
#               (216025, 0.02313586527426253)},
#              1030300: {(9877, 0.060219996398237316),
#               (36677, 0.07156986370395474),
#               (319680, 0.0617934573280807)},
#              1283105: {(45707, 0.023738018503464242),
#               (432124, 0.003128591212318649)},
#              1377707: {(146625, 0)},
#              704091: {(36290, 0.05829697190818523),
#               (325585, 0.11471110487914403),
#               (414571, 0.045125669559428844)},
#              172518: {(154896, 0.03501355905079878)},
#              1302577: {(47334, 0.07833795627077587),
#               (335418, 0.059083208128359224),
#               (361106, 0.06145596243614386)},
#              654925: {(13280, 0.12541603162293746)},
#              819372: {(23094, 0.034038636870668014),
#               (58752, 0.08235688754482456),
#               (225953, 0.07252494027426278)},
#              1041441: {(132729, 0.12421311332619578)},
#              65954: {(146586, 0.07055610109313605),
#               (350895, 0.08309198393385651),
#               (357229, 0.07399139979104807)},
#              939530: {(29741, 0.09025184729439863),
#               (105823, 0.07965551209457843),
#               (444931, 0.16574884903672427)},
#              676439: {(34269, 0.06914389207578879),
#               (36278, 0.09948556428227293)},
#              633087: {(326219, 0.014315529219631314)},
#              1358773: {(34364, 0.09700323427871291)},
#              33027: {(293139, 0.08592170794692235),
#               (428103, 0.08873692399642683),
#               (461091, 0.11401518687130016)},
#              462006: {(57275, 0.05043839493271483),
#               (323175, 0.01820690529783449),
#               (454818, 0.10174252080661139)},
#              20720: {(301531, 0.05802242823679395)},
#              1257132: {(251499, 0.10324998287339363)},
#              1268372: {(80284, 0.07093857621893762),
#               (85774, 0.051357516172117874)},
#              1150461: {(203594, 0.29487573464465466)},
#              418463: {(142881, 0), (245852, 0.0977212248119789)},
#              1019990: {(61926, 0.027518503720845106)},
#              251882: {(99610, 0.1494306432546912),
#               (372188, 0.10793287476006794)},
#              1174103: {(332295, 0.030229257800419997)},
#              292264: {(227976, 0.0920935545935443)},
#              726006: {(350968, 0.2580137516705017)},
#              767187: {(138367, 0.1502533848155482),
#               (238987, 0.08080142932277971)},
#              1262186: {(87438, 0.02136592758493339)},
#              79627: {(39959, 0.17964906732612762),
#               (349318, 0.18235490154298084)},
#              1332663: {(249854, 0)},
#              1265547: {(107752, 0.013142752920560687)},
#              54205: {(85089, 0.12492332901196036)},
#              1241112: {(306285, 0.16157275505306562)},
#              1059523: {(383802, 0.02542553387253924)},
#              1128342: {(400946, 0.025336040591169826)},
#              1319225: {(211610, 0.09903054521565283)},
#              1268600: {(261860, 0.12937708278240578),
#               (325256, 0.11134425045694832)},
#              650873: {(34943, 0.03821832563675502),
#               (403757, 0.05230773584293447)},
#              286199: {(50329, 0.08631768670550687),
#               (291885, 0.07353364123361573),
#               (297096, 0.08275223178167504)},
#              1193756: {(63846, 0.026458852968197805),
#               (442131, 0.07125727973620484),
#               (454818, 0.034061296380447456)},
#              1393377: {(294424, 0.11014819967382414)},
#              167704: {(124065, 0.1797776359173024),
#               (253286, 0.20264423943372242),
#               (368360, 0.20823464857436547)},
#              1273306: {(27020, 0.13938523083901597),
#               (51767, 0.0899404659107935),
#               (344552, 0.07965513677692344)},
#              468343: {(426220, 0.047814030129076084)},
#              694668: {(370037, 0.13013610835644077)},
#              896031: {(271537, 0.10947994135789259)},
#              91424: {(315543, 0.05937394091137183)},
#              442771: {(115631, 0.12226299925268927),
#               (280968, 0.12889016244233403)},
#              962643: {(299241, 0.026173321456288128)},
#              1273512: {(67707, 0.020522445520263274),
#               (177522, 0.033641494313321994)},
#              1189129: {(241530, 0.13023997673727952)},
#              858324: {(122931, 0.14649392814874865)},
#              1256293: {(133860, 0.20496066985843514),
#               (412945, 0.24769678997619082)},
#              470979: {(99601, 0.047559392860223024)},
#              694273: {(100507, 0.048403273896351955), (170052, 0)},
#              342556: {(155485, 0.11702010385083492)},
#              519705: {(130113, 0.13812675243243688),
#               (368069, 0.044764957033776184)},
#              1392360: {(264521, 0.11173959277108138),
#               (453286, 0.08463109780535302)},
#              59988: {(386604, 0.12052060501459914)},
#              561347: {(152263, 0.10980906505283476)},
#              340151: {(188169, 0)},
#              333054: {(217204, 0.000790090515018313),
#               (267504, 0.02964476572467495)},
#              662496: {(309652, 0)},
#              1073836: {(145721, 0.12623268766134724)},
#              713818: {(39321, 0.018258031219728924),
#               (230432, 0.015585047046198888)},
#              1338195: {(189110, 0.11288014020282153)},
#              1096666: {(191745, 0.10198389348056298),
#               (210223, 0.16524573224198258),
#               (359573, 0.10733848679772048)},
#              270464: {(77742, 0.21625808049344017),
#               (178112, 0.2462897080792844)},
#              814387: {(51275, 0.04717958906368039),
#               (157743, 0.043168098471532065)},
#              794751: {(111637, 0.09316720488392861),
#               (363663, 0.06439353097871131)},
#              805683: {(342004, 0.04521591324095943),
#               (463478, 0.1271553154614833)},
#              1207348: {(222888, 0.18584341732858656)},
#              625399: {(325310, 0.12960729892017803)},
#              766389: {(324290, 0.169219619061883)},
#              1058629: {(12217, 0.10162173948566725),
#               (406601, 0.12649542436271874)},
#              435551: {(184689, 0.07466327906084178)},
#              1098890: {(6605, 0.013278425746981546)},
#              1330925: {(372418, 0.07336435900345811)},
#              182550: {(421343, 0.030577439361265925)},
#              595183: {(301013, 0.08101676546429),
#               (421925, 0.09649163371732776)},
#              899857: {(256146, 0.4514600885524978)},
#              858230: {(179095, 0.049654333340196186),
#               (394809, 0.059144706414172084),
#               (463300, 0.05706686089224732)},
#              814292: {(6692, 0.06948806669532809),
#               (176189, 0.10416214714920813)},
#              572896: {(273104, 0.13608236774402452)},
#              677826: {(194992, 0.02462398292700016),
#               (399872, 0.07445536819855111)},
#              1210758: {(150445, 0.07470211031823967)},
#              323687: {(229588, 0.19034833620603225),
#               (390591, 0.2296731455436314)},
#              24840: {(46232, 0.25730480217467744),
#               (409804, 0.3628665068926932)},
#              256772: {(164828, 0.11566524715852708)},
#              1150304: {(88484, 0.06549928203451258),
#               (341409, 0.13384565287640088),
#               (350163, 0.11434946751743919)},
#              640623: {(46145, 0.024854576764139543),
#               (346886, 0.012119844805846377)},
#              874091: {(361712, 0.0609264248671073)},
#              1204332: {(213212, 0.05013551261287452)},
#              1215019: {(303960, 0.0891564561291354)},
#              429628: {(22969, 0.0932144862219795),
#               (199026, 0.09095894835640123),
#               (327214, 0.08958499558366159)},
#              894840: {(75659, 0.06481795420891341),
#               (316311, 0.08863885096510563)},
#              1266881: {(60120, 0.05963048438081852)},
#              1014730: {(191993, 0.08473434115941936)},
#              1397666: {(207734, 0.04714789338541356),
#               (212767, 0.04757583631324793),
#               (273761, 0.03687296408153687)},
#              4773: {(455911, 0.14107940140861977)},
#              953891: {(205392, 0.015210618640190656),
#               (396739, 0.007043499122064346)},
#              922006: {(225585, 0.11753718381647657),
#               (260282, 0.09993017430366455),
#               (354135, 0.12345758449121638)},
#              1009644: {(222097, 0.19764418268187003)},
#              686039: {(44590, 0.2621074270759318),
#               (77539, 0.3146780174320458)},
#              717336: {(240470, 0.0834723111743554),
#               (332918, 0.09503871802827721)},
#              630800: {(33087, 0.06219202838391576),
#               (161427, 0.08646681215884962)},
#              506533: {(93831, 0.09419577074742962),
#               (103021, 0.07175003750863237),
#               (325357, 0.05007711451834259)},
#              463575: {(361109, 0.011154147319737686)},
#              958883: {(22436, 0.06406247209706782)},
#              1366911: {(275779, 0.05379982061065201)},
#              875066: {(26747, 0.07774599483409532),
#               (100108, 0.07808635562014903),
#               (105203, 0.09286497770450927)},
#              1147244: {(77902, 0.06280633894177647),
#               (151187, 0),
#               (188228, 0.07216374160316844)},
#              139358: {(420631, 0.056349783352130575)},
#              732710: {(384157, 0.06203778284513248),
#               (428103, 0.07515211179133431),
#               (461091, 0.054161010633379456)},
#              892013: {(36166, 0.09584394071745829),
#               (310702, 0.09636744175261203),
#               (312728, 0.07328038814183804)},
#              995020: {(113042, 0.019352520107291014),
#               (291014, 0.06561585274976652)},
#              170268: {(4281, 0.03786293954098982),
#               (417227, 0.05002595526512206)},
#              403567: {(1653, 0.1221426695395321),
#               (147807, 0.12522739913555933),
#               (230813, 0.095430021987166)},
#              1134975: {(311017, 0.2439170759991428),
#               (312728, 0.31657017212253297),
#               (417912, 0.2578995918306015)},
#              756547: {(301721, 0.12870819363885078),
#               (345003, 0.048946093296293916)},
#              1195719: {(546, 0.10860043845233648), (252344, 0)},
#              24644: {(23109, 0.15507978648409237)},
#              761733: {(99042, 0.09940222372614697),
#               (213334, 0.06551803963292435),
#               (306020, 0.059599549250700316)},
#              1217389: {(211971, 0.05999840910523199),
#               (367495, 0.03873290960695389),
#               (422471, 0.03000049503903815)},
#              554931: {(181142, 0.015554596547859435)},
#              1210790: {(118120, 0), (406412, 0.05022256313655038)},
#              1379663: {(81185, 0.0076297442926437295),
#               (324183, 0.15245110406504483),
#               (338303, 0.03350934594928369)},
#              1231778: {(367490, 0.17061932567841975),
#               (384470, 0.12294067389567584)},
#              167682: {(55572, 0.05643518678209364)},
#              1061361: {(46924, 0.07833645338323728),
# ...
#              43183: {(39675, 0)},
#              270757: {(295537, 0.05478654082475198)},
#              597863: {(293719, 0.06693127250662664)},
#              745861: {(157899, 0.010601388051052554),
#               (399466, 0.06857283595015458)},
#              460378: {(339763, 0.028095965741368523)},
#              1349799: {(163495, 0)},
#              428181: {(376404, 0.053068287148840335)},
#              951430: {(222268, 0.20192040474984038)},
#              543659: {(345865, 0.005047886324587976)},
#              291869: {(152836, 0.11057682416161543),
#               (333099, 0.13431139269429804)},
#              18418: {(270378, 0.062043348998179176)},
#              1369915: {(88098, 0.1195841746813423)},
#              738654: {(156195, 0.03934848353910917)},
#              110412: {(171878, 0.20176551122442862)},
#              261500: {(301843, 0.05854774632365414)},
#              187244: {(125682, 0.016967943515067186)},
#              275531: {(157480, 0.04378642467076524)},
#              1107276: {(19677, 0.07230721462409687),
#               (175337, 0.07356715305205044),
#               (463804, 0.06428131956583238)},
#              654352: {(147709, 0.041458143582747166)},
#              45392: {(175332, 0.052615698987491355),
#               (392408, 0.11997761765482293)},
#              1196338: {(58869, 0.03443409935008646),
#               (324803, 0.047081223468387445)},
#              7846: {(268883, 0.10635000648378218),
#               (420960, 0.11326201886642474)},
#              1112963: {(366068, 0.08735741162186275)},
#              795423: {(47901, 0.04077831298092279)},
#              684678: {(72879, 0.07495877903950818)},
#              860141: {(180145, 0.06219592755872179)},
#              151844: {(208107, 0), (244789, 0.06918642560804017)},
#              460390: {(258120, 0.10710810291278572)},
#              954348: {(199018, 0.17397099251954806),
#               (274145, 0.09467524475733187),
#               (374129, 0.08565606611051742)},
#              299216: {(232568, 0.0016935953462173942)},
#              669861: {(210359, 0.05038240843740303)},
#              165938: {(64776, 0.08583376985554374)},
#              437168: {(276314, 0.08533746930518252),
#               (384302, 0.0970574551181998)},
#              1369889: {(153639, 0.0963639507158626),
#               (229137, 0.050219032974741944)},
#              1247528: {(411367, 0), (417342, 0.02252036883219239)},
#              672081: {(143946, 0)},
#              448185: {(176995, 0.1795996648944538)},
#              587353: {(216768, 0.1133683019857464)},
#              861299: {(213834, 0.34980962247383096),
#               (216266, 0.36370611627359195)},
#              113771: {(106322, 0)},
#              904918: {(36864, 0.11111505280979227),
#               (204023, 0.1734091759544029)},
#              682534: {(115631, 0.16534299134920138),
#               (147797, 0.10162963680373457),
#               (280968, 0.08119967627259467)},
#              1002084: {(201871, 0.02618099092420891)},
#              71606: {(168276, 0.05410820597002079),
#               (321257, 0.09138158486429417),
#               (413313, 0.03661370709351723)},
#              1052323: {(305656, 0.07150331031805959),
#               (389135, 0.08464846076209184),
#               (457045, 0.11971419968752296)},
#              535937: {(63935, 0.15009309887184275)},
#              430945: {(87562, 0.09102051717683163),
#               (258794, 0.09162801674893106)},
#              245010: {(25383, 0.05219789167058493)},
#              452149: {(442131, 0.11375737673215808)},
#              224127: {(271180, 0.05512423944086202)},
#              1064655: {(198684, 0.08037337649484413)},
#              527393: {(42873, 0.09161528884883534),
#               (298883, 0.06888924247821095)},
#              972641: {(113635, 0.055712508553105534),
#               (253264, 0.111956276531277)},
#              775335: {(46655, 0.03299548876224781)},
#              8653: {(172615, 0.022371566361350678),
#               (191566, 0.02555715508651951)},
#              1300620: {(56100, 0.11614582459053413)},
#              228669: {(127758, 0)},
#              804554: {(165823, 0.05164978407257114)},
#              929359: {(262815, 0.06588676198200061)},
#              1132875: {(29519, 0.061386393602599516),
#               (434791, 0.06251493593704599),
#               (462423, 0.11916059792849218)},
#              987393: {(268604, 0.020855216912671917)},
#              1395711: {(361200, 0.05911367291288626)},
#              1102098: {(12217, 0.0440379994790916),
#               (13925, 0.022989995957887806),
#               (399531, 0.023255893179317554)},
#              600191: {(375796, 0.08297505695514568)},
#              538281: {(20388, 0.018619986452700247), (93365, 0)},
#              896347: {(18252, 0.28965226747374057)},
#              540999: {(83570, 0.06984082577455183),
#               (85334, 0.15966111589015494)},
#              473043: {(127842, 0.1367781761495436),
#               (235946, 0.025843077246148243),
#               (466114, 0.19970071902364797)},
#              1256525: {(86532, 0.009149606868828944),
#               (369194, 0.053262932685740956),
#               (376911, 0.018002876130149625)},
#              156033: {(164035, 0.150054063526125)},
#              968544: {(368947, 0.026633636735019235)},
#              396758: {(97006, 0.040594478618212755),
#               (328314, 0.06002478716204828)},
#              457588: {(209849, 0.06111809611763112),
#               (432987, 0.04374797478818037)},
#              1399055: {(5895, 0.0026336908014783222),
#               (157555, 0.05896759093247391),
#               (436915, 0.0625492965699583)},
#              951855: {(287007, 0.04105911316638761)},
#              870345: {(12909, 0.040653918743959565)},
#              782927: {(77587, 0.06564922465442392),
#               (97843, 0.13100178261133893)},
#              80635: {(284648, 0.09536332584931678)},
#              1172355: {(149295, 0.039572887211746205)},
#              1270042: {(288778, 0.009279328064103469)},
#              980584: {(32344, 0.06621161414482463),
#               (57810, 0.0848731883751664),
#               (263319, 0.07766360978215106)},
#              1032492: {(78268, 0.25204658072492747),
#               (449391, 0.20762615162705822)},
#              816725: {(8786, 0.09774103902865466)},
#              830101: {(235437, 0.025882374729484056),
#               (372523, 0.08165387911001253)},
#              5551: {(81853, 0.034220308601082404)},
#              85590: {(192193, 0.02435865650532641)},
#              448930: {(14939, 0.067788743554032),
#               (348148, 0.09167933815982732)},
#              97205: {(79800, 0.031148386172437897),
#               (223670, 0.11457521793333628)},
#              327998: {(59691, 0.07127247693883396),
#               (129020, 0.11534111207019211),
#               (388622, 0.03026176774692406)},
#              1114575: {(150318, 0.08551978499202391),
#               (238766, 0.07796688521123302),
#               (266512, 0.05723626007740079)},
#              1258918: {(112047, 0.2006772118611445),
#               (291394, 0.11174244994495507),
#               (389158, 0.10154967289455108)},
#              290620: {(251663, 0.013510837978887885),
#               (422329, 0.028272869954346316)},
#              464410: {(32581, 0.39101207931648346)},
#              541053: {(21907, 0.08873012175116482),
#               (202922, 0.07752793281499568),
#               (375738, 0.09553467200231917)},
#              641005: {(266553, 0.05998544142616628),
#               (329738, 0.06357205655517868)},
#              223786: {(55108, 0.1104450770654716),
#               (58627, 0.017273062240009695)},
#              187439: {(103012, 0.05083425873541969),
#               (242188, 0.029016905914200634),
#               (447011, 0.058855042254646876)},
#              1378945: {(311341, 0.03569307312932952)},
#              1063593: {(239145, 0.11065679634669286),
#               (465522, 0.09982596563716205)},
#              898330: {(247909, 0.03576120931820558),
#               (310318, 0.04636854779391095)},
#              530773: {(143082, 0.047535349629283054)},
#              767773: {(430317, 0.034097651139908466)},
#              375439: {(410504, 0.06941804270157231),
#               (410582, 0.06563203701086773),
#               (420731, 0.11242715262044277)},
#              202730: {(57251, 0.23579520613939203),
#               (190534, 0.33551612983346624)},
#              1100135: {(428952, 0.07065218983639472)},
#              728881: {(456005, 0.05318495169231935)},
#              4256: {(91048, 0.0850198319377673)},
#              565492: {(272248, 0.3258734127616853),
#               (301721, 0.44069604522837824)},
#              976950: {(146306, 0.1691525304422276)},
#              873373: {(204494, 0.10348820737119052),
#               (338660, 0.08800436406831845)},
#              185603: {(198188, 0.07257155111272676),
#               (312699, 0.07292544466316364)},
#              981844: {(167534, 0.07256802503327608),
#               (410130, 0.05480519239959405)},
#              104532: {(138973, 0.11702642913624159),
#               (351397, 0.18127501253862716)},
#              1377507: {(84337, 0.12571747665299457),
#               (223003, 0.08183757715448269),
#               (463027, 0.07260743773448793)},
#              847579: {(391020, 0.11479818141353954)},
#              532419: {(193488, 0.09667977700824389),
#               (247059, 0.11878858999785358),
#               (358211, 0.09221044394735073)},
#              474017: {(286645, 0)},
#              928373: {(322104, 0.06090848916798094)},
#              1150253: {(80519, 0.16725704806079408)},
#              667292: {(59442, 0.05091112297686736),
#               (64881, 0.05549156068507863),
#               (312094, 0.04914150231539547)},
#              952859: {(341773, 0.08591838000819217),
#               (461708, 0.034586148892789964)},
#              1247126: {(78642, 0.02428481219199472),
#               (465554, 0.06897236691293777)},
#              990582: {(24734, 0.012380489680013176),
#               (108083, 0.03859303234378351)},
#              260253: {(275193, 0.05153473438367688),
#               (296795, 0.08903182061772938)},
#              1222579: {(133907, 0.07882720331527128),
#               (349002, 0.15308750877986335),
#               (374129, 0.052041528058046044)},
#              880463: {(142800, 0.10966240056218277)},
#              339546: {(66485, 0.08663581533756189),
#               (261979, 0.08598726743837298)},
#              215718: {(187946, 0), (358982, 0.06129018116406815)},
#              683066: {(337772, 0.13822025622259065),
#               (341482, 0.09670388075676746)},
#              670083: {(181067, 0.03211559144793544),
#               (272248, 0.02184445118175804)},
#              516682: {(208918, 0.07566118989253026)},
#              1347631: {(368839, 0.058438423807772207)},
#              565762: {(408019, 0.03924050566919752)},
#              828145: {(385475, 0.06673905252330438)},
#              1394949: {(78265, 0.016647777509665944)},
#              643871: {(431443, 0.08496566524769222)},
#              966752: {(162046, 0.1329806219561506)},
#              260178: {(196038, 0.04315114070059393),
#               (196366, 0.07109266812169676),
#               (217068, 0.0357929197207575)},
#              890859: {(40920, 0.12732536952517193)},
#              636755: {(102925, 0.16576249383084982),
#               (404604, 0.03275859096999875)},
#              118662: {(15327, 0.14452014372796293),
#               (266729, 0.10707211599942841)},
#              1144422: {(96127, 0.05870385955485066),
#               (308438, 0.052089299802382374)},
#              140282: {(415081, 0.038486660090380084)},
#              768267: {(466385, 0.009404757612008607)},
#              783557: {(67889, 0.0863000713411323),
#               (257655, 0.05300267051315137),
#               (458872, 0.051767766611251674)},
#              1026363: {(33661, 0.04977788878290057)},
#              856239: {(315017, 0.06359515480231145),
#               (366163, 0.07634425257614094)},
#              1393007: {(42002, 0.09509940695855862)},
#              1257856: {(344071, 0.04969751721082312)},
#              961107: {(382347, 0.04977463201090978)},
#              905027: {(234570, 0.03418241445711159)},
#              933752: {(427770, 0.020365850699276968),
#               (461199, 0.07403743317151765)},
#              ...})

# %%
accuracy.rmse(predictions_svd)
# Out:
# RMSE: 0.2579
# 0.25792569242440283

# %%
accuracy.rmse(knn_predictions)
# Out:
# RMSE: 0.2662
# 0.2662113475884163

# %%
precision_recall_at_3(knn_predictions, k=3)
# Out:
# precision@3: 0.00013831258644536652 recall@3: 0.00016136468418626097

# %%
precision_recall_at_3(predictions_svd, k=3)
# Out:
# precision@3: 0.0006454587367450437 recall@3: 0.0005215262684142352

# %%
# save the model
with open('SVD_model.pickle', 'wb') as file:
    pickle.dump(algo, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('SVD_model.pickle', 'rb') as file:
    loaded_svd = pickle.load(file)

# %% [markdown]
# ## Factorization machine, LightFM

# %%
# events_test = events_test[(events_test['visitorid'].isin(events_train['visitorid']))&(events_test['itemid'].isin(events_train['itemid']))]
id_cols=['visitorid','itemid']
trans_cat_train=dict()
trans_cat_test=dict()

for k in id_cols:
    cate_enc=LabelEncoder()
    trans_cat_train[k]=cate_enc.fit_transform(events_train[k].values)
    trans_cat_test[k]=cate_enc.transform(events_test[k].values)

# %%
ratings = dict()

cate_enc=LabelEncoder()
ratings['train'] = cate_enc.fit_transform(events_train.event)
ratings['test'] = cate_enc.transform(events_test.event)

# %%
n_users = len(np.unique(trans_cat_train['visitorid']))
n_items = len(np.unique(trans_cat_train['itemid']))

# %%
rate_matrix = dict()
rate_matrix['train'] = coo_matrix((ratings['train'], (trans_cat_train['visitorid'], trans_cat_train['itemid'])), shape=(n_users, n_items))
rate_matrix['test'] = coo_matrix((ratings['test'], (trans_cat_test['visitorid'], trans_cat_test['itemid'])), shape=(n_users, n_items))

# %%
rate_matrix
# Out:
# {'train': <66286x37623 sparse matrix of type '<class 'numpy.int32'>'
#  	with 666400 stored elements in COOrdinate format>,
#  'test': <66286x37623 sparse matrix of type '<class 'numpy.int32'>'
#  	with 45465 stored elements in COOrdinate format>}

# %%
model_fm = LightFM(no_components=10, loss='warp', random_state=42)
model_fm.fit(rate_matrix['train'], epochs=100, num_threads=8)

# %% [raw]
# #uncomment to save the fitted above LightFM model
# import pickle
# with open('model_fm.pickle', 'wb') as file:
#     pickle.dump(model_fm, file, protocol=pickle.HIGHEST_PROTOCOL)

# %% [raw]
#  with open('model_fm.pickle', 'rb') as f:
#         loaded_lfm = pickle.load(f)

# %%
precision_at_3 = precision_at_k(model_fm, rate_matrix['test'], k=3).mean()
precision_at_3
# Out:
# 0.026970956

# %%
auc_train = auc_score(model_fm, rate_matrix['train'], num_threads=8).mean()
auc_train
# Out:
# 0.9889925

# %% [markdown]
# 0.90670204
#
# 0.994286

# %%
auc_test = auc_score(model_fm, rate_matrix['test'], num_threads=8).mean()
auc_test
# Out:
# 0.73648226

# %% [markdown]
# 0.73648226
#
# 0.50134647

# %%
train_items = set(events_train['itemid'].values)
train_users = set(events_train['visitorid'].values)

# %%
[train_items]
# Out:
# [{6,
#   131080,
#   262159,
#   15,
#   262162,
#   19,
#   131096,
#   262169,
#   25,
#   131099,
#   26,
#   393240,
#   32,
#   262177,
#   393252,
#   131109,
#   131111,
#   42,
#   262186,
#   131118,
#   393266,
#   393268,
#   393274,
#   131131,
#   262205,
#   66,
#   262211,
#   393284,
#   393293,
#   393295,
#   262224,
#   102,
#   131178,
#   393324,
#   393328,
#   262258,
#   393334,
#   393336,
#   131196,
#   124,
#   131201,
#   262281,
#   147,
#   131219,
#   393368,
#   262297,
#   131234,
#   262310,
#   168,
#   393386,
#   393393,
#   262323,
#   190,
#   393412,
#   131270,
#   199,
#   393419,
#   204,
#   131278,
#   211,
#   262358,
#   216,
#   131294,
#   131298,
#   262371,
#   131311,
#   393458,
#   131314,
#   250,
#   262398,
#   257,
#   262407,
#   274,
#   131348,
#   131353,
#   131364,
#   393509,
#   393511,
#   262442,
#   131385,
#   131387,
#   315,
#   393533,
#   262462,
#   320,
#   393546,
#   262477,
#   334,
#   131407,
#   342,
#   131414,
#   393562,
#   348,
#   350,
#   393567,
#   361,
#   363,
#   131443,
#   371,
#   262519,
#   376,
#   262521,
#   262522,
#   381,
#   393598,
#   262525,
#   393601,
#   387,
#   131460,
#   262537,
#   393612,
#   393615,
#   262545,
#   403,
#   131479,
#   412,
#   262557,
#   393643,
#   131502,
#   433,
#   131509,
#   262595,
#   262596,
#   452,
#   393670,
#   456,
#   262603,
#   465,
#   466,
#   131542,
#   393686,
#   393689,
#   393691,
#   485,
#   262629,
#   262638,
#   496,
#   502,
#   131575,
#   262646,
#   506,
#   262651,
#   262653,
#   510,
#   393727,
#   131584,
#   393732,
#   393733,
#   262666,
#   262667,
#   393744,
#   262676,
#   534,
#   131609,
#   131611,
#   393756,
#   393761,
#   545,
#   262691,
#   546,
#   550,
#   393767,
#   393768,
#   262699,
#   393771,
#   393777,
#   262706,
#   262707,
#   563,
#   566,
#   131643,
#   572,
#   262722,
#   393799,
#   393803,
#   393809,
#   594,
#   393813,
#   393820,
#   609,
#   393828,
#   393830,
#   262762,
#   131696,
#   131703,
#   635,
#   393857,
#   131715,
#   393862,
#   131722,
#   651,
#   262797,
#   131727,
#   262800,
#   262799,
#   655,
#   131731,
#   131733,
#   131734,
#   668,
#   262813,
#   262815,
#   131745,
#   677,
#   262826,
#   262829,
#   393910,
#   393911,
#   262838,
#   697,
#   698,
#   393918,
#   262853,
#   393926,
#   709,
#   714,
#   131787,
#   262864,
#   393936,
#   262866,
#   131794,
#   720,
#   393944,
#   733,
#   262878,
#   131809,
#   131812,
#   393956,
#   743,
#   131816,
#   393966,
#   131828,
#   262902,
#   393978,
#   393979,
#   131835,
#   262907,
#   262915,
#   262917,
#   262919,
#   262920,
#   262923,
#   131858,
#   394003,
#   131861,
#   394005,
#   394007,
#   795,
#   131868,
#   131870,
#   131873,
#   131874,
#   262948,
#   262950,
#   394026,
#   131882,
#   394036,
#   821,
#   822,
#   262968,
#   827,
#   829,
#   394046,
#   131903,
#   832,
#   131907,
#   394052,
#   262980,
#   262982,
#   839,
#   131910,
#   394058,
#   262988,
#   262999,
#   856,
#   394073,
#   263008,
#   394080,
#   869,
#   263025,
#   394099,
#   885,
#   394103,
#   131963,
#   263036,
#   394116,
#   909,
#   394129,
#   263061,
#   263063,
#   394150,
#   394155,
#   263086,
#   132014,
#   132018,
#   394168,
#   963,
#   971,
#   132052,
#   263125,
#   982,
#   394199,
#   988,
#   394204,
#   132067,
#   132068,
#   997,
#   394212,
#   394217,
#   132074,
#   263145,
#   394220,
#   263154,
#   1011,
#   394229,
#   263164,
#   1022,
#   132100,
#   1035,
#   263182,
#   394254,
#   132114,
#   263188,
#   1046,
#   263191,
#   394267,
#   263195,
#   394269,
#   132126,
#   1054,
#   132124,
#   132131,
#   394276,
#   132137,
#   263210,
#   394283,
#   394285,
#   263217,
#   394290,
#   394293,
#   132156,
#   394304,
#   1090,
#   132165,
#   132168,
#   394315,
#   263245,
#   263251,
#   132182,
#   263258,
#   132187,
#   132188,
#   1115,
#   1118,
#   394349,
#   1142,
#   263287,
#   394360,
#   132222,
#   1152,
#   263302,
#   394375,
#   1161,
#   132234,
#   1164,
#   263312,
#   1171,
#   263316,
#   132245,
#   132246,
#   394391,
#   263319,
#   1175,
#   394406,
#   263336,
#   263338,
#   132267,
#   394411,
#   1211,
#   1217,
#   1224,
#   394441,
#   263374,
#   1233,
#   132307,
#   263385,
#   263386,
#   263397,
#   1255,
#   1261,
#   263409,
#   1267,
#   1268,
#   132343,
#   132347,
#   1278,
#   1279,
#   263438,
#   394518,
#   132377,
#   394534,
#   394536,
#   1325,
#   132399,
#   394544,
#   132401,
#   394548,
#   132413,
#   394561,
#   132418,
#   132417,
#   263492,
#   132423,
#   1353,
#   263501,
#   1360,
#   394580,
#   132437,
#   263509,
#   263512,
#   263513,
#   263516,
#   132445,
#   394590,
#   394592,
#   1377,
#   1378,
#   394594,
#   132453,
#   1382,
#   132463,
#   1392,
#   394608,
#   263537,
#   394607,
#   263547,
#   263558,
#   1415,
#   1423,
#   132505,
#   132507,
#   263583,
#   1443,
#   394660,
#   263589,
#   394663,
#   1449,
#   394666,
#   263596,
#   1455,
#   394678,
#   394679,
#   263608,
#   263606,
#   132555,
#   1489,
#   132567,
#   1510,
#   394732,
#   263661,
#   132591,
#   132594,
#   263670,
#   132600,
#   394745,
#   1531,
#   394747,
#   1538,
#   394754,
#   1543,
#   263689,
#   1546,
#   132619,
#   263692,
#   394766,
#   132624,
#   132633,
#   1562,
#   132637,
#   394782,
#   132638,
#   1568,
#   132640,
#   394786,
#   394792,
#   1590,
#   394809,
#   263741,
#   263744,
#   132672,
#   394818,
#   394819,
#   1605,
#   132683,
#   132686,
#   1614,
#   132689,
#   1619,
#   263765,
#   1622,
#   263767,
#   394840,
#   263769,
#   263768,
#   263771,
#   1634,
#   132707,
#   132714,
#   1644,
#   263792,
#   394865,
#   132720,
#   263797,
#   1653,
#   394872,
#   263801,
#   132729,
#   1659,
#   132733,
#   263807,
#   1664,
#   394882,
#   394883,
#   1668,
#   263819,
#   1681,
#   1682,
#   394899,
#   1684,
#   132756,
#   1688,
#   1698,
#   132772,
#   132776,
#   132779,
#   263852,
#   132783,
#   394931,
#   394932,
#   132792,
#   263871,
#   1732,
#   1757,
#   394974,
#   1766,
#   132839,
#   1768,
#   132845,
#   394994,
#   132853,
#   132854,
#   395002,
#   1786,
#   395005,
#   263942,
#   395017,
#   263956,
#   395029,
#   263958,
#   263959,
#   132893,
#   395041,
#   263971,
#   395045,
#   1829,
#   263980,
#   1845,
#   263993,
#   1852,
#   395068,
#   395071,
#   132946,
#   395091,
#   1879,
#   1880,
#   1891,
#   132965,
#   1894,
#   264039,
#   1895,
#   395111,
#   264044,
#   395121,
#   132980,
#   395132,
#   1920,
#   264067,
#   133001,
#   1931,
#   395152,
#   133013,
#   1945,
#   395161,
#   133019,
#   264094,
#   1956,
#   264111,
#   133042,
#   1976,
#   1977,
#   1978,
#   133052,
#   1981,
#   395196,
#   133055,
#   395201,
#   1985,
#   1987,
#   1986,
#   264133,
#   133067,
#   395211,
#   264142,
#   133071,
#   395216,
#   2006,
#   395222,
#   264152,
#   395225,
#   2008,
#   395227,
#   2020,
#   133103,
#   264178,
#   264179,
#   395251,
#   133110,
#   264183,
#   395265,
#   264194,
#   395273,
#   395274,
#   264206,
#   133138,
#   2070,
#   395292,
#   2076,
#   264221,
#   264223,
#   2082,
#   395298,
#   133157,
#   264233,
#   264236,
#   133168,
#   133169,
#   264243,
#   264246,
#   2104,
#   2110,
#   395326,
#   133183,
#   264256,
#   133186,
#   2115,
#   2119,
#   264265,
#   395343,
#   2129,
#   395350,
#   2135,
#   133209,
#   264281,
#   264284,
#   264286,
#   2142,
#   395358,
#   395361,
#   133224,
#   264297,
#   133226,
#   264301,
#   264306,
#   133236,
#   2165,
#   2166,
#   264311,
#   133244,
#   133247,
#   2175,
#   264322,
#   133255,
#   133256,
#   395405,
#   395407,
#   264338,
#   395413,
#   264349,
#   2206,
#   133282,
#   133285,
#   133287,
#   264361,
#   395435,
#   395438,
#   2227,
#   395446,
#   133302,
#   264379,
#   395451,
#   2235,
#   264384,
#   395457,
#   264386,
#   264392,
#   133323,
#   264397,
#   133326,
#   133330,
#   133332,
#   2263,
#   395482,
#   133341,
#   2270,
#   395487,
#   133349,
#   395496,
#   395497,
#   133353,
#   2288,
#   395508,
#   264436,
#   395522,
#   264454,
#   264456,
#   264461,
#   2317,
#   2319,
#   133398,
#   2329,
#   2331,
#   133404,
#   133408,
#   2342,
#   133415,
#   264488,
#   264491,
#   133419,
#   395566,
#   133423,
#   264496,
#   133431,
#   2364,
#   2368,
#   264513,
#   2369,
#   395589,
#   2374,
#   264521,
#   395596,
#   133456,
#   2386,
#   133463,
#   2396,
#   133472,
#   133476,
#   133485,
#   2416,
#   395633,
#   133490,
#   133493,
#   2422,
#   2421,
#   264574,
#   133504,
#   133505,
#   395648,
#   264579,
#   395656,
#   264586,
#   133517,
#   395661,
#   133521,
#   395668,
#   2453,
#   2455,
#   395672,
#   264604,
#   264605,
#   2463,
#   2469,
#   264614,
#   133549,
#   264636,
#   2496,
#   395715,
#   264645,
#   2504,
#   395731,
#   264661,
#   264662,
#   2520,
#   2521,
#   2524,
#   2526,
#   133603,
#   395749,
#   264685,
#   264686,
#   264689,
#   2548,
#   264693,
#   133627,
#   2559,
#   133632,
#   264706,
#   133638,
#   2567,
#   264715,
#   133647,
#   264727,
#   133658,
#   2587,
#   264732,
#   133662,
#   395809,
#   2594,
#   264746,
#   395823,
#   2610,
#   133684,
#   264756,
#   133686,
#   2616,
#   133693,
#   395843,
#   395845,
#   264774,
#   395846,
#   395849,
#   264778,
#   264777,
#   2640,
#   395857,
#   2641,
#   264789,
#   2651,
#   2657,
#   133729,
#   395873,
#   395876,
#   264801,
#   2661,
#   2660,
#   264807,
#   2665,
#   133738,
#   2669,
#   133751,
#   133753,
#   264829,
#   264832,
#   133761,
#   133764,
#   264838,
#   264846,
#   2710,
#   2711,
#   264858,
#   2716,
#   264861,
#   395935,
#   264876,
#   395952,
#   264881,
#   133814,
#   133818,
#   395965,
#   2750,
#   395969,
#   264897,
#   2765,
#   133837,
#   2769,
#   264913,
#   2771,
#   264915,
#   264917,
#   2775,
#   264924,
#   2785,
#   133860,
#   396007,
#   396008,
#   133867,
#   264942,
#   264947,
#   2809,
#   2810,
#   264958,
#   2817,
#   396036,
#   133894,
#   264967,
#   133895,
#   396042,
#   2826,
#   133898,
#   396045,
#   2829,
#   2828,
#   264972,
#   133906,
#   133907,
#   2836,
#   396053,
#   2838,
#   264978,
#   396064,
#   264993,
#   133924,
#   264997,
#   396071,
#   133929,
#   2861,
#   265005,
#   2863,
#   2864,
#   2867,
#   265012,
#   2873,
#   396094,
#   396097,
#   133954,
#   265026,
#   133961,
#   2890,
#   265033,
#   133964,
#   133966,
#   396110,
#   133968,
#   265038,
#   133970,
#   265041,
#   133972,
#   133974,
#   265046,
#   396124,
#   265054,
#   396128,
#   133985,
#   133986,
#   133989,
#   2918,
#   2917,
#   265082,
#   265085,
#   2942,
#   134013,
#   396160,
#   2956,
#   2958,
#   134030,
#   2961,
#   396177,
#   2966,
#   396183,
#   396185,
#   396186,
#   265113,
#   134045,
#   396189,
#   265119,
#   265120,
#   265122,
#   265124,
#   134053,
#   2980,
#   265133,
#   2992,
#   134064,
#   2998,
#   3000,
#   396223,
#   3016,
#   265163,
#   3020,
#   265165,
#   396238,
#   3024,
#   396241,
#   396243,
#   134108,
#   265186,
#   134116,
#   265188,
#   134118,
#   396265,
#   265202,
#   134131,
#   265204,
#   134135,
#   396281,
#   3066,
#   396284,
#   396288,
#   134148,
#   265227,
#   396303,
#   ...}]

# %%
trans_cat_test
# Out:
# {'visitorid': array([ 4659,  4659, 43746, ...,  7033, 12404,  7033], dtype=int64),
#  'itemid': array([26288, 26288, 27634, ...,  1719, 22716, 10829], dtype=int64)}

# %%
model_fm.predict(4569, [26288])
# Out:
# array([-5.4388304], dtype=float32)

# %%
all_items = list(train_items)

def get_predictions_lfm(user_id, top_k=3):
    predictions = model_fm.predict(user_id, all_items)
    inds = np.arfsort(predictions)[::-1]
    return inds[:top_k]

predictions_lfm = {}

for user_id in events_test['visitorid'].drop_duplicates().values:
    predictions_user = get_predictions_lfm(int(user_id), top_k=3)
    predictions[user_id] = predictions_user.tolist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[156], line 11
#       8 predictions_lfm = {}
#      10 for user_id in events_test['visitorid'].drop_duplicates().values:
# ---> 11     predictions_user = get_predictions_lfm(int(user_id), top_k=3)
#      12     predictions[user_id] = predictions_user.tolist()
#
# Cell In[156], line 4, in get_predictions_lfm(user_id, top_k)
#       3 def get_predictions_lfm(user_id, top_k=3):
# ----> 4     predictions = model_fm.predict(user_id, all_items)
#       5     inds = np.arfsort(predictions)[::-1]
#       6     return inds[:top_k]
#
# File ~\anaconda3\lib\site-packages\lightfm\lightfm.py:817, in LightFM.predict(self, user_ids, item_ids, item_features, user_features, num_threads)
#     814 n_users = user_ids.max() + 1
#     815 n_items = item_ids.max() + 1
# --> 817 (user_features, item_features) = self._construct_feature_matrices(
#     818     n_users, n_items, user_features, item_features
#     819 )
#     821 lightfm_data = self._get_lightfm_data()
#     823 predictions = np.empty(len(user_ids), dtype=np.float32)
#
# File ~\anaconda3\lib\site-packages\lightfm\lightfm.py:325, in LightFM._construct_feature_matrices(self, n_users, n_items, user_features, item_features)
#     323 if self.user_embeddings is not None:
#     324     if not self.user_embeddings.shape[0] >= user_features.shape[1]:
# --> 325         raise ValueError(
#     326             "The user feature matrix specifies more "
#     327             "features than there are estimated "
#     328             "feature embeddings: {} vs {}.".format(
#     329                 self.user_embeddings.shape[0], user_features.shape[1]
#     330             )
#     331         )
#     333 if self.item_embeddings is not None:
#     334     if not self.item_embeddings.shape[0] >= item_features.shape[1]:
#
# ValueError: The user feature matrix specifies more features than there are estimated feature embeddings: 66286 vs 100895.

# %%
predictions_lfm[4659]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 predictions_lfm[4659]
#
# KeyError: 4659

# %% [markdown]
# ## Recommender

# %%
def recommend_3(user_id, model):
    """Returns 3 recomendations of item-id for user with input id"""
    
    try:
        user_id = int(user_id)
        
        #make predictions for user for each item
        uid_predictions = []
        
        for item in events.itemid.unique():
            prediction = model.predict(user_id, item)
            
            if prediction.details['was_impossible'] == False:
                uid_predictions.append(prediction)
                
        if len(uid_predictions)==0:
            return "No visitor with this Id"
        
        else: 
            uid_predictions.sort(key=lambda x: x.est, reverse=True)
            recommendations = [i.iid for i in uid_predictions[:3]]
            return ' '.join(str(i) for i in recommendations)
    
    except TypeError:
        return "Please, check the value inserted. It must be integer."

# %%
recommend_3(, loaded_svd)
# Out:
# '324079 1115 184011'

# %%
recommend_3(542702, loaded_KNN)
# Out:
# 'No visitor with this Id'

# %%
recommend_3(542702, model_fm)
# Out:
# 'Please, check the value inserted. It must be integer.'

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# autopep8            1.6.0
# lightfm             1.16
# matplotlib          3.5.2
# numpy               1.23.5
# pandas              1.4.4
# scipy               1.9.1
# seaborn             0.11.2
# session_info        1.0.0
# sklearn             1.0.2
# surprise            1.1.3
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         9.2.0
# asttokens                   NA
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# bottleneck                  1.3.5
# cffi                        1.15.1
# colorama                    0.4.5
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# entrypoints                 0.4
# executing                   2.0.1
# google                      NA
# hypergeom_ufunc             NA
# importlib_metadata          NA
# ipykernel                   6.15.2
# ipython_genutils            0.2.0
# ipywidgets                  7.6.5
# jedi                        0.18.1
# jinja2                      3.1.3
# joblib                      1.2.0
# jupyter_server              1.18.1
# kiwisolver                  1.4.2
# lz4                         3.1.3
# markupsafe                  2.0.1
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# nbinom_ufunc                NA
# ncf_ufunc                   NA
# nt                          NA
# ntsecuritycon               NA
# numexpr                     2.8.3
# packaging                   21.3
# parso                       0.8.3
# pickleshare                 0.7.5
# pkg_resources               NA
# prompt_toolkit              3.0.43
# psutil                      5.9.0
# pure_eval                   0.2.2
# pycodestyle                 2.8.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.11.2
# pyparsing                   3.0.9
# pythoncom                   NA
# pytz                        2022.1
# pywintypes                  NA
# ruamel                      NA
# setuptools                  63.4.1
# six                         1.16.0
# sphinxcontrib               NA
# stack_data                  0.6.3
# statsmodels                 0.13.2
# threadpoolctl               2.2.0
# tornado                     6.1
# traitlets                   5.1.1
# typing_extensions           NA
# wcwidth                     0.2.5
# win32api                    NA
# win32com                    NA
# win32security               NA
# zipp                        NA
# zmq                         23.2.0
# zope                        NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.12.3
# jupyter_client      7.3.4
# jupyter_core        4.11.1
# jupyterlab          3.4.4
# notebook            6.4.12
# -----
# Python 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
# Windows-10-10.0.19045-SP0
# -----
# Session information updated at 2024-02-23 20:15
# </pre>
# </details>

# %% [markdown]
# ## Notes 'n scratches

# %% [raw]
# def sample_recommendation(model, data, user_ids):
#
#     n_users, n_items = data['train'].shape
#
#     for user_id in user_ids:
#         known_positives = data['itemid'][data['train'].tocsr()[user_id].indices]
#
#         scores = model.predict(user_id, np.arange(n_items))
#         top_items = data['itemid'][np.argsort(-scores)]
#
#         print("User %s" % user_id)
#         print("     Known positives:")
#
#         for x in known_positives[:3]:
#             print("        %s" % x)
#
#         print("     Recommended:")
#
#         for x in top_items[:3]:
#             print("        %s" % x)

# %% [raw]
# sample_recommendation(loaded_lfm, trans_cat_train, [1150086])

# %% [raw]
# ## Xgboost classification

# %% [raw]
# # target definition
# #events_train.columns
# # Label encode  переменные

# %% [raw]
# X_train = events_train.drop(columns=['rating'])
# y_train = events_train['rating']
# X_test = events_test.drop(columns=['rating'])
# y_test = events_test['rating']

# %% [raw]
# from xgboost import XGBClassifier

# %% [raw]
# xgb_clf = XGBClassifier()

# %% [raw]
# X_train.dtypes

# %% [raw]
# # multiclass classification
# import pandas
# import xgboost
# from sklearn import model_selection
# from sklearn.metrics import accuracy_score
# from sklearn.preprocessing import LabelEncoder

# %% [raw]
# # load data
# data = pandas.read_csv('iris.csv', header=None)
# dataset = data.values
# # split data into X and y
# X = dataset[:,0:4]
# Y = dataset[:,4]

# %% [raw]
# Y = events.rating

# %% [raw]
# # encode string class values as integers
# label_encoder = LabelEncoder()
# label_encoder = label_encoder.fit(Y)
# label_encoded_y = label_encoder.transform(Y)
# seed = 7
# test_size = 0.33
# X_train, X_test, y_train, y_test = model_selection.train_test_split(X, label_encoded_y, test_size=test_size, random_state=seed)
# # fit model no training data
# model = xgboost.XGBClassifier()
# model.fit(X_train, y_train)
# print(model)
# # make predictions for test data
# y_pred = model.predict(X_test)
# predictions = [round(value) for value in y_pred]
# # evaluate predictions
# accuracy = accuracy_score(y_test, predictions)
# print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %% [raw]
# xgb_clf.fit(X_train, y_train)

# %% [raw]
# y_pred = xgb_clf.predict(X_test)

# %% [raw]
# # Calculate accuracy
# accuracy = xgb_clf.score(X_test, y_test)
# print("Accuracy: %.2f%%" % (accuracy * 100.0))
